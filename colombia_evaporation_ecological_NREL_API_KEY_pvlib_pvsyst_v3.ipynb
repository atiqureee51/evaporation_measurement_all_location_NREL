# %% [markdown]
# # Evaporation and cover measurment initials

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pvlib
# !pip install timezonefinder
# !pip install numpy-financial
# !pip install nrel-pysam
# Out:
# Collecting pvlib
#   Downloading pvlib-0.10.2-py3-none-any.whl (29.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pvlib) (1.23.5)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from pvlib) (1.5.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from pvlib) (2023.3.post1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pvlib) (2.31.0)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from pvlib) (1.11.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from pvlib) (3.9.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.0->pvlib) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pvlib) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pvlib) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pvlib) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pvlib) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.25.0->pvlib) (1.16.0)
# Installing collected packages: pvlib
# Successfully installed pvlib-0.10.2
# Collecting timezonefinder
#   Downloading timezonefinder-6.2.0.tar.gz (46.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 33.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi<2,>=1.15.1 in /usr/local/lib/python3.10/dist-packages (from timezonefinder) (1.16.0)
# Collecting h3<4,>=3.7.6 (from timezonefinder)
#   Downloading h3-3.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 60.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1.18 in /usr/local/lib/python3.10/dist-packages (from timezonefinder) (1.23.5)
# Requirement already satisfied: setuptools>=65.5 in /usr/local/lib/python3.10/dist-packages (from timezonefinder) (67.7.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi<2,>=1.15.1->timezonefinder) (2.21)
# Building wheels for collected packages: timezonefinder
#   Building wheel for timezonefinder (pyproject.toml) ... done
#   Created wheel for timezonefinder: filename=timezonefinder-6.2.0-cp310-cp310-manylinux_2_35_x86_64.whl size=46900638 sha256=7a453abba2f38786c0daafb4bf75366674a33ce49234e7a2c40ab88be088ce5f
#   Stored in directory: /root/.cache/pip/wheels/17/19/d4/ae94459b7f74f7e8f171862d1c08adedf9b7c76ddfc514a620
# Successfully built timezonefinder
# Installing collected packages: h3, timezonefinder
# Successfully installed h3-3.7.6 timezonefinder-6.2.0
# Collecting numpy-financial
#   Downloading numpy_financial-1.0.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from numpy-financial) (1.23.5)
# Installing collected packages: numpy-financial
# Successfully installed numpy-financial-1.0.0
# Collecting nrel-pysam
#   Downloading NREL_PySAM-4.2.0-cp310-cp310-manylinux2014_x86_64.whl (46.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 18.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from nrel-pysam) (1.5.3)
# Collecting python-dotenv (from nrel-pysam)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from nrel-pysam) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nrel-pysam) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nrel-pysam) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->nrel-pysam) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->nrel-pysam) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->nrel-pysam) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->nrel-pysam) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->nrel-pysam) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->nrel-pysam) (1.16.0)
# Installing collected packages: python-dotenv, nrel-pysam
# Successfully installed nrel-pysam-4.2.0 python-dotenv-1.0.0

# %% [markdown]
# # For any location evaporation measurement using NREL API KEy

# %%
import io
import requests
import pandas as pd
import pvlib
from json import JSONDecodeError
import warnings
from pvlib._deprecation import pvlibDeprecationWarning
import numpy as np
import numpy_financial as npf
import datetime
import xarray as xr
import math
#import cupy as cp
from timezonefinder import TimezoneFinder
from pvlib.tools import sind
from pvlib._deprecation import warn_deprecated
from pvlib.tools import _get_sample_intervals
import scipy
import scipy.constants
import warnings
import json
import PySAM.Pvsamv1 as pvsam
from PySAM import Utilityrate5 as ur5  # Add this import statement
#import pysam
import os
from io import StringIO
import copy
import tempfile
from math import pi, cos, sin, tan, acos, sqrt, log, exp




# 'relative_humidity', 'total_precipitable_water' are not available
ATTRIBUTES = (
    'air_temperature', 'dew_point', 'dhi', 'dni', 'ghi', 'surface_albedo',
    'surface_pressure', 'wind_direction', 'wind_speed')
PVLIB_PYTHON = 'pvlib python'

# Dictionary mapping PSM3 names to pvlib names
VARIABLE_MAP = {
    'GHI': 'ghi',
    'DHI': 'dhi',
    'DNI': 'dni',
    'Clearsky GHI': 'ghi_clear',
    'Clearsky DHI': 'dhi_clear',
    'Clearsky DNI': 'dni_clear',
    'Solar Zenith Angle': 'solar_zenith',
    'Temperature': 'temp_air',
    'Relative Humidity': 'relative_humidity',
    'Dew point': 'temp_dew',
    'Pressure': 'pressure',
    'Wind Direction': 'wind_direction',
    'Wind Speed': 'wind_speed',
    'Surface Albedo': 'albedo',
    'Precipitable Water': 'precipitable_water',
}


def get_psm3(latitude, longitude, api_key, email, names='tmy', interval=60,
             attributes=ATTRIBUTES, leap_day=None, full_name=PVLIB_PYTHON,
             affiliation=PVLIB_PYTHON, map_variables=None, timeout=30, reservoir_name=""):
    # The well know text (WKT) representation of geometry notation is strict.
    # A POINT object is a string with longitude first, then the latitude, with
    # four decimals each, and exactly one space between them.
    longitude = ('%9.4f' % longitude).strip()
    latitude = ('%8.4f' % latitude).strip()
    # TODO: make format_WKT(object_type, *args) in tools.py

    # convert to string to accomodate integer years being passed in
    names = str(names)

    # convert pvlib names in attributes to psm3 convention (reverse mapping)
    # unlike psm3 columns, attributes are lower case and with underscores
    amap = {value: key.lower().replace(' ', '_') for (key, value) in
            VARIABLE_MAP.items()}
    attributes = [amap.get(a, a) for a in attributes]
    attributes = list(set(attributes))  # remove duplicate values

    if (leap_day is None) and (not names.startswith('t')):
        warnings.warn(
            'The ``get_psm3`` function will default to leap_day=True '
            'starting in pvlib 0.11.0. Specify leap_day=True '
            'to enable this behavior now, or specify leap_day=False '
            'to hide this warning.', pvlibDeprecationWarning)
        leap_day = False

    # required query-string parameters for request to PSM3 API
    params = {
        'api_key': api_key,
        'full_name': full_name,
        'email': email,
        'affiliation': affiliation,
        'reason': PVLIB_PYTHON,
        'mailing_list': 'false',
        'wkt': 'POINT(%s %s)' % (longitude, latitude),
        'names': names,
        'attributes':  ','.join(attributes),
        'leap_day': str(leap_day).lower(),
        'utc': 'false',
        'interval': interval
    }
    NSRDB_API_BASE = "https://developer.nrel.gov"
    PSM_URL1 = NSRDB_API_BASE + "/api/nsrdb/v2/solar/psm3-download.csv"
    TMY_URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/psm3-tmy-download.csv"
    PSM5MIN_URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/psm3-5min-download.csv"

    # First, check longitude conditions
    if -16 < lon < 91:
        PSM_URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/msg-iodc-download.csv"
    elif 91 < lon < 182:
        PSM_URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/himawari-download.csv"
    else:
        # Then check latitude conditions if longitude didn't match
        if lat >= -21.186575058950382:
            PSM_URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/psm3-2-2-tmy-download.csv"
        else:
            PSM_URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/full-disc-download.csv"

    # Finally, set URL based on interval and 'names' prefix
    if any(prefix in names for prefix in ('tmy', 'tgy', 'tdy')):
        URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/psm3-2-2-tmy-download.csv"
    elif interval in (5, 15):
        URL = PSM5MIN_URL
    else:
        URL = PSM_URL

    response = requests.get(URL, params=params, timeout=timeout)

    if not response.ok:
        # if the API key is rejected, then the response status will be 403
        # Forbidden, and then the error is in the content and there is no JSON
        try:
            errors = response.json()['errors']
        except JSONDecodeError:
            errors = response.content.decode('utf-8')
        raise requests.HTTPError(errors, response=response)
    # the CSV is in the response content as a UTF-8 bytestring
    # to use pandas we need to create a file buffer from the response
    fbuf = io.StringIO(response.content.decode('utf-8'))
    return parse_psm3(fbuf, map_variables, reservoir_name)



def parse_psm3(fbuf, map_variables=None, reservoir_name=""):
    # Read metadata
    metadata_fields = fbuf.readline().split(',')
    metadata_fields[-1] = metadata_fields[-1].strip()
    metadata_values = fbuf.readline().split(',')
    metadata_values[-1] = metadata_values[-1].strip()
    metadata = dict(zip(metadata_fields, metadata_values))

    # Set some metadata types to numbers
    metadata['Local Time Zone'] = int(metadata['Local Time Zone'])
    metadata['Time Zone'] = int(metadata['Time Zone'])
    metadata['Latitude'] = float(metadata['Latitude'])
    metadata['Longitude'] = float(metadata['Longitude'])
    metadata['Elevation'] = int(metadata['Elevation'])

    # Read weather data
    columns = fbuf.readline().split(',')
    columns[-1] = columns[-1].strip()
    columns = [col for col in columns if col != '']
    dtypes = dict.fromkeys(columns, float)
    dtypes.update(Year=int, Month=int, Day=int, Hour=int, Minute=int)
    dtypes['Cloud Type'] = int
    dtypes['Fill Flag'] = int
    data = pd.read_csv(
        fbuf, header=None, names=columns, usecols=columns, dtype=dtypes,
        delimiter=',', lineterminator='\n')

    # Convert date vector to datetime
    dtidx = pd.to_datetime(
        data[['Year', 'Month', 'Day', 'Hour', 'Minute']])
    tz = 'Etc/GMT%+d' % -metadata['Time Zone']
    data.index = pd.DatetimeIndex(dtidx).tz_localize(tz)

    # Rename PSM3 variable names to SAM-compatible names
    data = data.rename(columns=VARIABLE_MAP)
    # Rearrange columns to match the expected order
    #data = data[['Year', 'Month', 'Day', 'Hour', 'Minute', 'DNI', 'DHI', 'GHI', 'Dew Point', 'Temperature', 'Pressure', 'Wind Direction', 'Wind Speed', 'Surface Albedo']]
    data=data[['Year', 'Month', 'Day', 'Hour', 'Minute', 'dni', 'dhi', 'ghi', 'Dew Point', 'temp_air', 'pressure', 'wind_direction', 'wind_speed', 'albedo']]
    #Year	Month	Day	Hour	Minute	wind_speed	dhi	ghi	pressure	wind_direction	albedo	dni	temp_air	Dew Point

    # Add a "Timestamp" column
    #data['Timestamp'] = data.index.strftime('%Y%m%d:%H%M')

    # Create SAM-compatible file header
    header = [
        'Source,Location ID,City,State,Country,Latitude,Longitude,Time Zone,Elevation,Local Time Zone,Dew Point Units,DHI Units,DNI Units,GHI Units,Temperature Units,Pressure Units,Wind Direction Units,Wind Speed Units,Surface Albedo Units,Version\n',
        'NSRDB,{},-,-,-,{},{},{},{},{},C,w/m2,w/m2,w/m2,C,mbar,Degrees,m/s,N/A,3.1.0\n'.format(metadata["Location ID"], metadata["Latitude"], metadata["Longitude"], metadata["Time Zone"], metadata["Elevation"], metadata["Local Time Zone"]),
        'Year,Month,Day,Hour,Minute,DNI,DHI,GHI,Dew Point,Temperature,Pressure,Wind Direction,Wind Speed,Surface Albedo\n',
    ]
    header_str = ''.join(header)
    print(f"Debug: Reservoir name inside parse_psm3: {reservoir_name}")
    # Write SAM-compatible file

    # Your desired directory
    directory_path = "/content/drive/MyDrive/Colombia_nrel_all_location/"
    # Updated SAM-compatible file path
    sam_weather_file = f"{directory_path}sam_weather_file_{reservoir_name}_{lat}_{lon}.csv"

    #sam_weather_file = f"sam_weather_file_{reservoir_name}+_{lat}_+{lon}.csv"
    with open(sam_weather_file, 'w') as sam_file:
        sam_file.write(header_str)
        data.to_csv(sam_file, index=False, header=False, sep=',')

    return data, metadata, sam_weather_file


def download_weather_data(lat, lon, reservoir_name):
    #dataset = "2021"  ## for southern brazil only 2019,2021, 2022 dta available
    dataset="tmy-2021"
    '''
    if lat>=-21.186575058950382:
      dataset = "tmy-2021"
    else:
      dataset = "2021"
    '''
    #api_key = "qguVH9fdgUOyRo1jo6zzOUXkS6a96vY1ct45RpuK"
    #url = f"https://developer.nrel.gov/api/nsrdb/v2/solar/psm3-download.csv?wkt=POINT({lon}%20{lat})&names={dataset}&leap_day=false&interval=60&utc=false&full_name=Your%20Name&email=atiqureee@gmail.com&affiliation=Your%20Organization&mailing_list=true&reason=example&api_key={api_key}&attributes=dhi,dni,ghi,clearsky_dhi,clearsky_dni,clearsky_ghi,cloud_type,dew_point,air_temperature,surface_albedo,surface_pressure,relative_humidity,temperature_2m_nwp,precipitable_water,wind_direction_10m_nwp,wind_speed_10m_nwp,wind_speed_100m_nwp"

    #response = requests.get(url)
    #response.raise_for_status()

    #return StringIO(response.text)
    email='atiqureee@gmail.com'
    NREL_API_KEY='qguVH9fdgUOyRo1jo6zzOUXkS6a96vY1ct45RpuK'

    weather, metadata, sam_weather_file = get_psm3(lat, lon, NREL_API_KEY, email, names=dataset, interval=60,
                                                   attributes=('air_temperature', 'dew_point', 'dhi', 'dni', 'ghi',
                                                               'surface_albedo', 'surface_pressure', 'wind_direction',
                                                               'wind_speed'), leap_day=False, full_name='pvlib python',
                                                   affiliation='pvlib python', map_variables=None, timeout=60, reservoir_name=reservoir_name)
    print(f"Debug: Reservoir name inside download_weather_data: {reservoir_name}")
    temp_file = tempfile.NamedTemporaryFile(delete=False, suffix=".csv")
    temp_file.close()
    weather.to_csv(temp_file.name, index=False)

    # Create a new "Time" column using the "Year," "Month," "Day," and "Hour" columns
    weather["Time"] = pd.to_datetime(weather[["Year", "Month", "Day", "Hour"]])

    # Calculate average monthly albedo values
    weather["Month"] = pd.to_datetime(weather["Time"]).dt.month
    albedo_column = "albedo" if "albedo" in weather.columns else "Surface Albedo"
    monthly_albedo = weather.groupby("Month")[albedo_column].mean().tolist()


    return sam_weather_file, monthly_albedo, weather, metadata



def sapm_cell_FPV(poa_global, temp_air, wind_speed, a, b, deltaT,
              irrad_ref=1000.):

    module_temperature = sapm_module_FPV(poa_global, temp_air, wind_speed,
                                     a, b)
    return sapm_cell_from_module_FPV(module_temperature, poa_global, deltaT,
                                 irrad_ref)


def sapm_module_FPV(poa_global, temp_air, wind_speed, a, b):

    return poa_global * np.exp(a + b * wind_speed) + temp_air

def sapm_cell_from_module_FPV(module_temperature, poa_global, deltaT,
                          irrad_ref=1000.):

    return module_temperature + (poa_global / irrad_ref) * deltaT

def pvsyst_cell_fpv(poa_global, temp_air, wind_speed=1.0, u_c=29.0, u_v=0.0,
                eta_m=None, module_efficiency=0.1, alpha_absorption=0.9):

    if eta_m:
        warn_deprecated(
            since='v0.9', message='eta_m overwriting module_efficiency',
            name='eta_m', alternative='module_efficiency', removal='v0.10')
        module_efficiency = eta_m
    total_loss_factor = u_c + u_v * wind_speed
    heat_input = poa_global * alpha_absorption * (1 - module_efficiency)
    temp_difference = heat_input / total_loss_factor
    return temp_air + temp_difference

def pvsyst_cell_pv(poa_global, temp_air, wind_speed=1.0, u_c=29.0, u_v=0.0,
                eta_m=None, module_efficiency=0.1, alpha_absorption=0.9):

    if eta_m:
        warn_deprecated(
            since='v0.9', message='eta_m overwriting module_efficiency',
            name='eta_m', alternative='module_efficiency', removal='v0.10')
        module_efficiency = eta_m
    total_loss_factor = u_c + u_v * wind_speed
    heat_input = poa_global * alpha_absorption * (1 - module_efficiency)
    temp_difference = heat_input / total_loss_factor
    return temp_air + temp_difference


# Read the .xlsx file
filename = '/content/Main_ALL_colombia_qgis_DDSA_OSM_v27_colabmerged.xlsx'
data = pd.read_excel(filename, sheet_name='calculation all important ')
output_csv = "output.csv"
# Conversion factor for ET to E
conversion_factor_et_to_e = 0.8
# DataFrames to store the results
evaporation_df = pd.DataFrame()
rmse_results_E = {}
# DataFrames to store the results
evaporation_df = pd.DataFrame()

# Assuming 'data' is your dataframe with 440 rows of lat_osm, lon_osm, area_osm, and ID

# Daily evaporation dataframe for the first 29 rows
# Aggregate evaporation dataframe for all 440 locations
aggregate_evaporation_columns = ['ID', 'lat_osm', 'lon_osm', 'avg_daily_evaporation', 'total_yearly_evaporation', 'evaporation_saved_by_fcover_m3']
aggregate_evaporation_df = pd.DataFrame(columns=aggregate_evaporation_columns)


#data = pd.read_csv(input_csv)
data["PV annual energy (kWh)"] = 0.0

for index, row in data.iterrows():
        print(f"Running case number: {index} grid: {index}")

        lat = row['latitude_all']
        lon = row["longitude_all"]
        ID=row["ID_ALL"]
        ReservoirArea = row['Reservoir_area_all_km2']
        reservoir_name = f"{ID}_"
        PanelArea = 0.3 * ReservoirArea

        if PanelArea > 6:
          PanelArea = 6
        #PanelArea = row["SURFACE_AREA"]
        #area_km2 = row["SURFACE_AREA"]
        #pv_kw = 0.3 * area_acres * (1 / 6) * 1000  # for every 1MW there are 6 acres land requires but we chose 2.5


        #area_acres = PanelArea * 247.105  # Convert km² to acres
        #pv_kw = area_acres * (1 / 2.5) * 1000 # thye have given total areas 30% we already did that so area comes to acres

        module_area_m2_fromtotal_PVarea=(771/1265)*PanelArea*1000000
        sam_weather_file_data, albedo_data, weather_full_dataframe, metadata  = download_weather_data(lat, lon, reservoir_name)
        # Set the Time column as the index
        for col in ['ghi', 'dni', 'dhi']:
          weather_full_dataframe[f"{col}_MJ_m2"] = weather_full_dataframe[col] * 3600 / 10**6

        # Set the Time column as the index
        weather_full_dataframe.set_index('Time', inplace=True)

        # Resample to daily frequency
        weather_daily = weather_full_dataframe.resample('D').agg({
            'Year': 'first',
            'Month': 'first',
            'Day': 'first',
            'ghi_MJ_m2': 'sum',
            'dni_MJ_m2': 'sum',
            'dhi_MJ_m2': 'sum',
            'temp_air': ['mean', 'max', 'min'],  # mean, max, and min temperature
            'wind_speed': 'mean',
            'pressure': 'mean',
            'Dew Point': 'mean',
            'wind_direction': 'mean',
            'albedo': 'mean'
        })

        # Flatten the multi-level columns
        weather_daily.columns = [' '.join(col).strip() for col in weather_daily.columns.values]

        # Rename columns for max and min temperature
        weather_daily.rename(columns={'temp_air max': 'Ta. Max.', 'temp_air min': 'Ta. Min.'}, inplace=True)

        # Reset index
        weather_daily.reset_index(drop=True, inplace=True)


        #pv_system = pvsam.new()
        #pv_system = pvsam.default("FlatPlatePVCommercial")
        #evaporation determination
        data_sheet = copy.deepcopy(weather_daily)

        # Read the original Excel file to get the original values
        original_data = copy.deepcopy(data_sheet)
        total_average_reservoir_area_km2 = ReservoirArea # in km²
        fpv_area = PanelArea*1000000  # in m2
        fpv_openings = (199.81/1265)* fpv_area  # in m2
        total_reservoir_area_m2 = total_average_reservoir_area_km2 * 1e6
        coverage_ratio=(fpv_area-fpv_openings)/total_reservoir_area_m2
        #ghi
        data_sheet["Rs (MJ/m²d) solar irrdaiance"]=copy.deepcopy(data_sheet['ghi_MJ_m2 sum'])
        # Calculations
        data_sheet["Rns (MJ/m²d)"] = (1 - data_sheet["albedo mean"]) * data_sheet["Rs (MJ/m²d) solar irrdaiance"]
        data_sheet["φ Dec."] = -25.50
        data_sheet["φ Rad. (latitude)"] = (pi / 180) * lat
        data_sheet["dr (rad) (inverse relative distance Earth-Sun)"] = 1 + 0.033 * np.cos(2 * pi / 365 * data_sheet["Day first"])
        data_sheet["δ (rad) solar declination"] = 0.409 * np.sin((2 * pi * data_sheet["Day first"] / 365) - 1.39)
        data_sheet["ωs (sunset hour angle)"] = np.arccos(-np.tan(data_sheet["φ Rad. (latitude)"]) * np.tan(data_sheet["δ (rad) solar declination"]))

        data_sheet["sin(φ)*sin(δ)"] = np.sin(data_sheet["φ Rad. (latitude)"]) * np.sin(data_sheet["δ (rad) solar declination"])
        data_sheet["cos(φ)*cos(δ)"] = np.cos(data_sheet["φ Rad. (latitude)"]) * np.cos(data_sheet["δ (rad) solar declination"])
        data_sheet["Ra(MJ m-2d-1)"] = 37.586 * data_sheet["dr (rad) (inverse relative distance Earth-Sun)"] * (
            data_sheet["sin(φ)*sin(δ)"] + data_sheet["cos(φ)*cos(δ)"] * np.sin(data_sheet["ωs (sunset hour angle)"]))
        data_sheet["N (h)"] = 24 / pi * data_sheet["ωs (sunset hour angle)"]
        data_sheet["Rso(MJ m-2d-1)"] = (0.75 + (0.00002 * metadata['Elevation'])) * data_sheet["Ra(MJ m-2d-1)"]
        data_sheet["σ(MJm²dia-1)"] = 4.903e-9
        data_sheet["Ta. Av."]=data_sheet['temp_air mean']

        data_sheet["ea (kPa)"] = 0.6108 * np.exp((17.27 * data_sheet["Dew Point mean"]) / (237.3 + data_sheet["Dew Point mean"]))
        data_sheet["es.max (kPa)"] = 0.6108 * np.exp(17.3 * data_sheet["Ta. Max."] / (237.3 + data_sheet["Ta. Max."]))
        data_sheet["es.min (kPa)"] = 0.6108 * np.exp(17.3 * data_sheet["Ta. Min."] / (237.3 + data_sheet["Ta. Min."]))
        data_sheet["es (kPa)"] = (data_sheet["es.max (kPa)"] + data_sheet["es.min (kPa)"]) / 2

        #data_sheet["Rnl(MJ m-2d-1)"]  =   (1.35 * np.minimum(data_sheet["Rs (MJ/m²d) solar irrdaiance"] / data_sheet["Rso(MJ m-2d-1)"], 1) - 0.35)*(0.34 - 0.14 * np.sqrt(data_sheet["ea (kPa)"])) * data_sheet["σ(MJm²dia-1)"] * (data_sheet["Ta. Av."] + 273.2)**4
        #data_sheet["Rnl(MJ m-2d-1)"]  =   (1.35 * (data_sheet["Rs (MJ/m²d) solar irrdaiance"] / data_sheet["Rso(MJ m-2d-1)"]) - 0.35)*(0.34 - 0.14 * np.sqrt(data_sheet["ea (kPa)"])) * data_sheet["σ(MJm²dia-1)"] * (data_sheet["Ta. Av."] + 273.2)**4

        data_sheet["Rnl(MJ m-2d-1)"] = data_sheet["σ(MJm²dia-1)"] * ((data_sheet["Ta. Max."] + 273.16)**4 + (data_sheet["Ta. Min."] + 273.16)**4 / 2)* (0.34 - 0.14 * np.sqrt(data_sheet["ea (kPa)"])) * (1.35 * (data_sheet["Rs (MJ/m²d) solar irrdaiance"] / data_sheet["Rso(MJ m-2d-1)"]) - 0.35)

        data_sheet["Rn (MJ m-2d-1)"] = data_sheet["Rns (MJ/m²d)"] - data_sheet["Rnl(MJ m-2d-1)"]

        data_sheet["Rns_fcover (MJ/m²d)"]  = 0
        data_sheet["Rnl_fcover(MJ m-2d-1)"]= data_sheet["σ(MJm²dia-1)"] * ((data_sheet["Ta. Max."] + 273.16)**4 + (data_sheet["Ta. Min."] + 273.16)**4 / 2)* (0.34 - 0.14 * np.sqrt(data_sheet["ea (kPa)"])) * (0.1)
        data_sheet["Rn_fcover (MJ m-2d-1)"] = data_sheet["Rns_fcover (MJ/m²d)"] - data_sheet["Rnl_fcover(MJ m-2d-1)"]

        data_sheet["λ (MJ.kg-1)"] = 2.501 - data_sheet["Ta. Av."] * (2.361e-3)
        data_sheet["Patm(kPa)"] = 101.3 * (((293 - (0.0065 * metadata['Elevation'])) / 293) ** 5.26)
        data_sheet["γ(kPa/ºC)"] = (0.665e-3) * data_sheet["Patm(kPa)"]


        # no humdity is here so
        #data_sheet["ea (kPa)"] = (data_sheet["es (kPa)"] * data_sheet["U.avg.%"]) / 100


        data_sheet["dew point (C)"] = (237.3 * np.log10(data_sheet["ea (kPa)"] / 0.6108)) / (7.5 - np.log10(data_sheet["ea (kPa)"] / 0.6108))

        data_sheet["ed (kpa)"] = 0.6108 * np.exp(17.3 * data_sheet["dew point (C)"] / (237.3 + data_sheet["dew point (C)"]))

        data_sheet["Δ (kPa/ºC)"] = 4098 * ((0.6108 * np.exp(17.3 * data_sheet["Ta. Av."] / (237.3 + data_sheet["Ta. Av."]))) / ((data_sheet["Ta. Av."] + 273.2) ** 2))

        data_sheet["D (kPa)"] = data_sheet["es (kPa)"] - data_sheet["ea (kPa)"]
        #data_sheet["D (kPa)"] = data_sheet["D (kPa)"].apply(lambda x: max(0, x))

        ## penmen monteith ((0.408 * AE2 * W2) + ((Y2 * 900 * G2 * (AB2 - AD2)) / (C2 + 273))) / (AE2 + Y2 * (1 + 0.34 * G2))
        data_sheet["Penman-Monteith equation ET (mm/day) (2021)"] = ((0.408 * data_sheet["Δ (kPa/ºC)"] * data_sheet["Rn (MJ m-2d-1)"]) + ((data_sheet["γ(kPa/ºC)"] * 900 * data_sheet["wind_speed mean"] * (data_sheet["D (kPa)"])) / (data_sheet["Ta. Av."] + 273))) / (data_sheet["Δ (kPa/ºC)"] + data_sheet["γ(kPa/ºC)"] * (1 + 0.34 * data_sheet["wind_speed mean"]))
        # Rower equation ET (mm/day) (2021-2022)

        data_sheet["Penman-Monteith equation ET (mm/day) _method3_fcover(2021)"]= ((0.408 * data_sheet["Δ (kPa/ºC)"] *(data_sheet["Rn (MJ m-2d-1)"] * (1 - coverage_ratio) + data_sheet["Rn_fcover (MJ m-2d-1)"] * coverage_ratio)) + ((data_sheet["γ(kPa/ºC)"] * 900 * data_sheet["wind_speed mean"] * (data_sheet["D (kPa)"])) / (data_sheet["Ta. Av."] + 273))) / (data_sheet["Δ (kPa/ºC)"]+ data_sheet["γ(kPa/ºC)"] * (1 + 0.34 * data_sheet["wind_speed mean"]))


        ## evaporation
        surface_area_km2 = total_average_reservoir_area_km2
        surface_area_m2 = surface_area_km2 * 1e6
        effective_open_area_m2 = (surface_area_m2 - fpv_area) + fpv_openings
        sliced_method_data = data_sheet["Penman-Monteith equation ET (mm/day) (2021)"] * conversion_factor_et_to_e
        free_evaporation_hm3 = (sliced_method_data / 1000) * surface_area_km2

        fcover_evaporation_hm3 = (data_sheet["Penman-Monteith equation ET (mm/day) _method3_fcover(2021)"]* conversion_factor_et_to_e / 1000) * effective_open_area_m2 / 1e6

        savings_method_3_m3 = (free_evaporation_hm3.sum()- fcover_evaporation_hm3.sum())*1e6

        # Other calculations for water savings methods 1, 2, 3...
        if index < 29:
          evaporation_df[f"{reservoir_name} free evaporation E mm/day"] = sliced_method_data
          evaporation_df[f"{reservoir_name} free evaporation (m3)"] = free_evaporation_hm3*1e6
          evaporation_df[f"{reservoir_name} fcover evaporation using water savings method 3 E mm/day"] = data_sheet["Penman-Monteith equation ET (mm/day) _method3_fcover(2021)"]* conversion_factor_et_to_e
          evaporation_df[f"{reservoir_name} fcover evaporation using water savings method 3 E m3/day"]=fcover_evaporation_hm3*1e6
          #evaporation_df[f"{reservoir_name} water savings by method 3 (m3)"] =savings_method_3_m3
            # Compute aggregate values for all locations
        avg_daily_evaporation = sliced_method_data.mean()
        total_yearly_evaporation = sliced_method_data.sum()
        evaporation_saved_by_fcover_m3 = savings_method_3_m3

        aggregate_evaporation_df.loc[index] = [ID, lat, lon, avg_daily_evaporation, total_yearly_evaporation, evaporation_saved_by_fcover_m3]

# Truncate lat_osm and lon_osm in aggregate_evaporation_df

# Save dataframes to files (compatible with Google Colab)
evaporation_df.to_csv('/content/drive/MyDrive/Colombia_nrel_all_location/daily_evaporation_colombia_v27.csv', index=False)
aggregate_evaporation_df.to_csv('/content/drive/MyDrive/Colombia_nrel_all_location/ALL_aggregate_evaporation_colombia_v27.csv', index=False)




# Adding Penman-Monteith Method 3 to evaporation_df
# Code for Penman-Monteith Method 3...

# Displaying the evaporation DataFrame
evaporation_df.head()
# Out:
# Running case number: 0 grid: 0
# Debug: Reservoir name inside parse_psm3: 312_
# Debug: Reservoir name inside download_weather_data: 312_
# Running case number: 1 grid: 1
# Debug: Reservoir name inside parse_psm3: 279_
# Debug: Reservoir name inside download_weather_data: 279_
# Running case number: 2 grid: 2
# Debug: Reservoir name inside parse_psm3: 113_
# Debug: Reservoir name inside download_weather_data: 113_
# Running case number: 3 grid: 3
# Debug: Reservoir name inside parse_psm3: 426_
# Debug: Reservoir name inside download_weather_data: 426_
# Running case number: 4 grid: 4
# Debug: Reservoir name inside parse_psm3: 303_
# Debug: Reservoir name inside download_weather_data: 303_
# Running case number: 5 grid: 5
# Debug: Reservoir name inside parse_psm3: 117_
# Debug: Reservoir name inside download_weather_data: 117_
# Running case number: 6 grid: 6
# Debug: Reservoir name inside parse_psm3: 298_
# Debug: Reservoir name inside download_weather_data: 298_
# Running case number: 7 grid: 7
# Debug: Reservoir name inside parse_psm3: 216_
# Debug: Reservoir name inside download_weather_data: 216_
# Running case number: 8 grid: 8
# Debug: Reservoir name inside parse_psm3: 300_
# Debug: Reservoir name inside download_weather_data: 300_
# Running case number: 9 grid: 9
# Debug: Reservoir name inside parse_psm3: 116_
# Debug: Reservoir name inside download_weather_data: 116_
# Running case number: 10 grid: 10
# Debug: Reservoir name inside parse_psm3: 159_
# Debug: Reservoir name inside download_weather_data: 159_
# Running case number: 11 grid: 11
# Debug: Reservoir name inside parse_psm3: 118_
# Debug: Reservoir name inside download_weather_data: 118_
# Running case number: 12 grid: 12
# Debug: Reservoir name inside parse_psm3: 42_
# Debug: Reservoir name inside download_weather_data: 42_
# Running case number: 13 grid: 13
# Debug: Reservoir name inside parse_psm3: 296_
# Debug: Reservoir name inside download_weather_data: 296_
# Running case number: 14 grid: 14
# Debug: Reservoir name inside parse_psm3: 114_
# Debug: Reservoir name inside download_weather_data: 114_
# Running case number: 15 grid: 15
# Debug: Reservoir name inside parse_psm3: 74_
# Debug: Reservoir name inside download_weather_data: 74_
# Running case number: 16 grid: 16
# Debug: Reservoir name inside parse_psm3: 316_
# Debug: Reservoir name inside download_weather_data: 316_
# Running case number: 17 grid: 17
# Debug: Reservoir name inside parse_psm3: 160_
# Debug: Reservoir name inside download_weather_data: 160_
# Running case number: 18 grid: 18
# Debug: Reservoir name inside parse_psm3: 204_
# Debug: Reservoir name inside download_weather_data: 204_
# Running case number: 19 grid: 19
# Debug: Reservoir name inside parse_psm3: 440_
# Debug: Reservoir name inside download_weather_data: 440_
# Running case number: 20 grid: 20
# Debug: Reservoir name inside parse_psm3: 302_
# Debug: Reservoir name inside download_weather_data: 302_
# Running case number: 21 grid: 21
# Debug: Reservoir name inside parse_psm3: 122_
# Debug: Reservoir name inside download_weather_data: 122_
# Running case number: 22 grid: 22
# Debug: Reservoir name inside parse_psm3: 48_
# Debug: Reservoir name inside download_weather_data: 48_
# Running case number: 23 grid: 23
# Debug: Reservoir name inside parse_psm3: 297_
# Debug: Reservoir name inside download_weather_data: 297_
# Running case number: 24 grid: 24
# Debug: Reservoir name inside parse_psm3: 110_
# Debug: Reservoir name inside download_weather_data: 110_
# Running case number: 25 grid: 25
# Debug: Reservoir name inside parse_psm3: 254_
# Debug: Reservoir name inside download_weather_data: 254_
# <ipython-input-9-334ccbd3ee26>:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} free evaporation E mm/day"] = sliced_method_data
# <ipython-input-9-334ccbd3ee26>:462: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} free evaporation (m3)"] = free_evaporation_hm3*1e6
# <ipython-input-9-334ccbd3ee26>:463: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} fcover evaporation using water savings method 3 E mm/day"] = data_sheet["Penman-Monteith equation ET (mm/day) _method3_fcover(2021)"]* conversion_factor_et_to_e
# <ipython-input-9-334ccbd3ee26>:464: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} fcover evaporation using water savings method 3 E m3/day"]=fcover_evaporation_hm3*1e6
# Running case number: 26 grid: 26
# Debug: Reservoir name inside parse_psm3: 5_
# Debug: Reservoir name inside download_weather_data: 5_
# <ipython-input-9-334ccbd3ee26>:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} free evaporation E mm/day"] = sliced_method_data
# <ipython-input-9-334ccbd3ee26>:462: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} free evaporation (m3)"] = free_evaporation_hm3*1e6
# <ipython-input-9-334ccbd3ee26>:463: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} fcover evaporation using water savings method 3 E mm/day"] = data_sheet["Penman-Monteith equation ET (mm/day) _method3_fcover(2021)"]* conversion_factor_et_to_e
# <ipython-input-9-334ccbd3ee26>:464: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} fcover evaporation using water savings method 3 E m3/day"]=fcover_evaporation_hm3*1e6
# Running case number: 27 grid: 27
# Debug: Reservoir name inside parse_psm3: 438_
# Debug: Reservoir name inside download_weather_data: 438_
# <ipython-input-9-334ccbd3ee26>:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} free evaporation E mm/day"] = sliced_method_data
# <ipython-input-9-334ccbd3ee26>:462: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} free evaporation (m3)"] = free_evaporation_hm3*1e6
# <ipython-input-9-334ccbd3ee26>:463: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} fcover evaporation using water savings method 3 E mm/day"] = data_sheet["Penman-Monteith equation ET (mm/day) _method3_fcover(2021)"]* conversion_factor_et_to_e
# <ipython-input-9-334ccbd3ee26>:464: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} fcover evaporation using water savings method 3 E m3/day"]=fcover_evaporation_hm3*1e6
# Running case number: 28 grid: 28
# Debug: Reservoir name inside parse_psm3: 123_
# Debug: Reservoir name inside download_weather_data: 123_
# <ipython-input-9-334ccbd3ee26>:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} free evaporation E mm/day"] = sliced_method_data
# <ipython-input-9-334ccbd3ee26>:462: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} free evaporation (m3)"] = free_evaporation_hm3*1e6
# <ipython-input-9-334ccbd3ee26>:463: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} fcover evaporation using water savings method 3 E mm/day"] = data_sheet["Penman-Monteith equation ET (mm/day) _method3_fcover(2021)"]* conversion_factor_et_to_e
# <ipython-input-9-334ccbd3ee26>:464: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   evaporation_df[f"{reservoir_name} fcover evaporation using water savings method 3 E m3/day"]=fcover_evaporation_hm3*1e6
# Running case number: 29 grid: 29
# Debug: Reservoir name inside parse_psm3: 427_
# Debug: Reservoir name inside download_weather_data: 427_
# Running case number: 30 grid: 30
# Debug: Reservoir name inside parse_psm3: 14_
# Debug: Reservoir name inside download_weather_data: 14_
# Running case number: 31 grid: 31
# Debug: Reservoir name inside parse_psm3: 255_
# Debug: Reservoir name inside download_weather_data: 255_
# Running case number: 32 grid: 32
# Debug: Reservoir name inside parse_psm3: 337_
# Debug: Reservoir name inside download_weather_data: 337_
# Running case number: 33 grid: 33
# Debug: Reservoir name inside parse_psm3: 149_
# Debug: Reservoir name inside download_weather_data: 149_
# Running case number: 34 grid: 34
# Debug: Reservoir name inside parse_psm3: 292_
# Debug: Reservoir name inside download_weather_data: 292_
# Running case number: 35 grid: 35
# Debug: Reservoir name inside parse_psm3: 6_
# Debug: Reservoir name inside download_weather_data: 6_
# Running case number: 36 grid: 36
# Debug: Reservoir name inside parse_psm3: 13_
# Debug: Reservoir name inside download_weather_data: 13_
# Running case number: 37 grid: 37
# Debug: Reservoir name inside parse_psm3: 43_
# Debug: Reservoir name inside download_weather_data: 43_
# Running case number: 38 grid: 38
# Debug: Reservoir name inside parse_psm3: 203_
# Debug: Reservoir name inside download_weather_data: 203_
# Running case number: 39 grid: 39
# Debug: Reservoir name inside parse_psm3: 317_
# Debug: Reservoir name inside download_weather_data: 317_
# Running case number: 40 grid: 40
# Debug: Reservoir name inside parse_psm3: 11_
# Debug: Reservoir name inside download_weather_data: 11_
# Running case number: 41 grid: 41
# Debug: Reservoir name inside parse_psm3: 439_
# Debug: Reservoir name inside download_weather_data: 439_
# Running case number: 42 grid: 42
# Debug: Reservoir name inside parse_psm3: 7_
# Debug: Reservoir name inside download_weather_data: 7_
# Running case number: 43 grid: 43
# Debug: Reservoir name inside parse_psm3: 18_
# Debug: Reservoir name inside download_weather_data: 18_
# Running case number: 44 grid: 44
# Debug: Reservoir name inside parse_psm3: 15_
# Debug: Reservoir name inside download_weather_data: 15_
# Running case number: 45 grid: 45
# Debug: Reservoir name inside parse_psm3: 264_
# Debug: Reservoir name inside download_weather_data: 264_
# Running case number: 46 grid: 46
# Debug: Reservoir name inside parse_psm3: 270_
# Debug: Reservoir name inside download_weather_data: 270_
# Running case number: 47 grid: 47
# Debug: Reservoir name inside parse_psm3: 115_
# Debug: Reservoir name inside download_weather_data: 115_
# Running case number: 48 grid: 48
# Debug: Reservoir name inside parse_psm3: 19_
# Debug: Reservoir name inside download_weather_data: 19_
# Running case number: 49 grid: 49
# Debug: Reservoir name inside parse_psm3: 306_
# Debug: Reservoir name inside download_weather_data: 306_
# Running case number: 50 grid: 50
# Debug: Reservoir name inside parse_psm3: 148_
# Debug: Reservoir name inside download_weather_data: 148_
# Running case number: 51 grid: 51
# Debug: Reservoir name inside parse_psm3: 4_
# Debug: Reservoir name inside download_weather_data: 4_
# Running case number: 52 grid: 52
# Debug: Reservoir name inside parse_psm3: 12_
# Debug: Reservoir name inside download_weather_data: 12_
# Running case number: 53 grid: 53
# Debug: Reservoir name inside parse_psm3: 354_
# Debug: Reservoir name inside download_weather_data: 354_
# Running case number: 54 grid: 54
# Debug: Reservoir name inside parse_psm3: 280_
# Debug: Reservoir name inside download_weather_data: 280_
# Running case number: 55 grid: 55
# Debug: Reservoir name inside parse_psm3: 150_
# Debug: Reservoir name inside download_weather_data: 150_
# Running case number: 56 grid: 56
# Debug: Reservoir name inside parse_psm3: 420_
# Debug: Reservoir name inside download_weather_data: 420_
# Running case number: 57 grid: 57
# Debug: Reservoir name inside parse_psm3: 261_
# Debug: Reservoir name inside download_weather_data: 261_
# Running case number: 58 grid: 58
# Debug: Reservoir name inside parse_psm3: 223_
# Debug: Reservoir name inside download_weather_data: 223_
# Running case number: 59 grid: 59
# Debug: Reservoir name inside parse_psm3: 362_
# Debug: Reservoir name inside download_weather_data: 362_
# Running case number: 60 grid: 60
# Debug: Reservoir name inside parse_psm3: 417_
# Debug: Reservoir name inside download_weather_data: 417_
# Running case number: 61 grid: 61
# Debug: Reservoir name inside parse_psm3: 27_
# Debug: Reservoir name inside download_weather_data: 27_
# Running case number: 62 grid: 62
# Debug: Reservoir name inside parse_psm3: 224_
# Debug: Reservoir name inside download_weather_data: 224_
# Running case number: 63 grid: 63
# Debug: Reservoir name inside parse_psm3: 10_
# Debug: Reservoir name inside download_weather_data: 10_
# Running case number: 64 grid: 64
# Debug: Reservoir name inside parse_psm3: 430_
# Debug: Reservoir name inside download_weather_data: 430_
# Running case number: 65 grid: 65
# Debug: Reservoir name inside parse_psm3: 21_
# Debug: Reservoir name inside download_weather_data: 21_
# Running case number: 66 grid: 66
# Debug: Reservoir name inside parse_psm3: 17_
# Debug: Reservoir name inside download_weather_data: 17_
# Running case number: 67 grid: 67
# Debug: Reservoir name inside parse_psm3: 257_
# Debug: Reservoir name inside download_weather_data: 257_
# Running case number: 68 grid: 68
# Debug: Reservoir name inside parse_psm3: 368_
# Debug: Reservoir name inside download_weather_data: 368_
# Running case number: 69 grid: 69
# Debug: Reservoir name inside parse_psm3: 79_
# Debug: Reservoir name inside download_weather_data: 79_
# Running case number: 70 grid: 70
# Debug: Reservoir name inside parse_psm3: 84_
# Debug: Reservoir name inside download_weather_data: 84_
# Running case number: 71 grid: 71
# Debug: Reservoir name inside parse_psm3: 85_
# Debug: Reservoir name inside download_weather_data: 85_
# Running case number: 72 grid: 72
# Debug: Reservoir name inside parse_psm3: 299_
# Debug: Reservoir name inside download_weather_data: 299_
# Running case number: 73 grid: 73
# Debug: Reservoir name inside parse_psm3: 134_
# Debug: Reservoir name inside download_weather_data: 134_
# Running case number: 74 grid: 74
# Debug: Reservoir name inside parse_psm3: 22_
# Debug: Reservoir name inside download_weather_data: 22_
# Running case number: 75 grid: 75
# Debug: Reservoir name inside parse_psm3: 70_
# Debug: Reservoir name inside download_weather_data: 70_
# Running case number: 76 grid: 76
# Debug: Reservoir name inside parse_psm3: 9_
# Debug: Reservoir name inside download_weather_data: 9_
# Running case number: 77 grid: 77
# Debug: Reservoir name inside parse_psm3: 20_
# Debug: Reservoir name inside download_weather_data: 20_
# Running case number: 78 grid: 78
# Debug: Reservoir name inside parse_psm3: 419_
# Debug: Reservoir name inside download_weather_data: 419_
# Running case number: 79 grid: 79
# Debug: Reservoir name inside parse_psm3: 131_
# Debug: Reservoir name inside download_weather_data: 131_
# Running case number: 80 grid: 80
# Debug: Reservoir name inside parse_psm3: 77_
# Debug: Reservoir name inside download_weather_data: 77_
# Running case number: 81 grid: 81
# Debug: Reservoir name inside parse_psm3: 41_
# Debug: Reservoir name inside download_weather_data: 41_
# Running case number: 82 grid: 82
# Debug: Reservoir name inside parse_psm3: 16_
# Debug: Reservoir name inside download_weather_data: 16_
# Running case number: 83 grid: 83
# Debug: Reservoir name inside parse_psm3: 310_
# Debug: Reservoir name inside download_weather_data: 310_
# Running case number: 84 grid: 84
# Debug: Reservoir name inside parse_psm3: 359_
# Debug: Reservoir name inside download_weather_data: 359_
# Running case number: 85 grid: 85
# Debug: Reservoir name inside parse_psm3: 437_
# Debug: Reservoir name inside download_weather_data: 437_
# Running case number: 86 grid: 86
# Debug: Reservoir name inside parse_psm3: 8_
# Debug: Reservoir name inside download_weather_data: 8_
# Running case number: 87 grid: 87
# Debug: Reservoir name inside parse_psm3: 162_
# Debug: Reservoir name inside download_weather_data: 162_
# Running case number: 88 grid: 88
# Debug: Reservoir name inside parse_psm3: 301_
# Debug: Reservoir name inside download_weather_data: 301_
# Running case number: 89 grid: 89
# Debug: Reservoir name inside parse_psm3: 236_
# Debug: Reservoir name inside download_weather_data: 236_
# Running case number: 90 grid: 90
# Debug: Reservoir name inside parse_psm3: 237_
# Debug: Reservoir name inside download_weather_data: 237_
# Running case number: 91 grid: 91
# Debug: Reservoir name inside parse_psm3: 242_
# Debug: Reservoir name inside download_weather_data: 242_
# Running case number: 92 grid: 92
# Debug: Reservoir name inside parse_psm3: 243_
# Debug: Reservoir name inside download_weather_data: 243_
# Running case number: 93 grid: 93
# Debug: Reservoir name inside parse_psm3: 245_
# Debug: Reservoir name inside download_weather_data: 245_
# Running case number: 94 grid: 94
# Debug: Reservoir name inside parse_psm3: 341_
# Debug: Reservoir name inside download_weather_data: 341_
# Running case number: 95 grid: 95
# Debug: Reservoir name inside parse_psm3: 235_
# Debug: Reservoir name inside download_weather_data: 235_
# Running case number: 96 grid: 96
# Debug: Reservoir name inside parse_psm3: 234_
# Debug: Reservoir name inside download_weather_data: 234_
# Running case number: 97 grid: 97
# Debug: Reservoir name inside parse_psm3: 34_
# Debug: Reservoir name inside download_weather_data: 34_
# Running case number: 98 grid: 98
# Debug: Reservoir name inside parse_psm3: 369_
# Debug: Reservoir name inside download_weather_data: 369_
# Running case number: 99 grid: 99
# Debug: Reservoir name inside parse_psm3: 244_
# Debug: Reservoir name inside download_weather_data: 244_
# Running case number: 100 grid: 100
# Debug: Reservoir name inside parse_psm3: 340_
# Debug: Reservoir name inside download_weather_data: 340_
# Running case number: 101 grid: 101
# Debug: Reservoir name inside parse_psm3: 347_
# Debug: Reservoir name inside download_weather_data: 347_
# Running case number: 102 grid: 102
# Debug: Reservoir name inside parse_psm3: 158_
# Debug: Reservoir name inside download_weather_data: 158_
# Running case number: 103 grid: 103
# Debug: Reservoir name inside parse_psm3: 276_
# Debug: Reservoir name inside download_weather_data: 276_
# Running case number: 104 grid: 104
# Debug: Reservoir name inside parse_psm3: 295_
# Debug: Reservoir name inside download_weather_data: 295_
# Running case number: 105 grid: 105
# Debug: Reservoir name inside parse_psm3: 241_
# Debug: Reservoir name inside download_weather_data: 241_
# Running case number: 106 grid: 106
# Debug: Reservoir name inside parse_psm3: 249_
# Debug: Reservoir name inside download_weather_data: 249_
# Running case number: 107 grid: 107
# Debug: Reservoir name inside parse_psm3: 132_
# Debug: Reservoir name inside download_weather_data: 132_
# Running case number: 108 grid: 108
# Debug: Reservoir name inside parse_psm3: 233_
# Debug: Reservoir name inside download_weather_data: 233_
# Running case number: 109 grid: 109
# Debug: Reservoir name inside parse_psm3: 246_
# Debug: Reservoir name inside download_weather_data: 246_
# Running case number: 110 grid: 110
# Debug: Reservoir name inside parse_psm3: 247_
# Debug: Reservoir name inside download_weather_data: 247_
# Running case number: 111 grid: 111
# Debug: Reservoir name inside parse_psm3: 105_
# Debug: Reservoir name inside download_weather_data: 105_
# Running case number: 112 grid: 112
# Debug: Reservoir name inside parse_psm3: 274_
# Debug: Reservoir name inside download_weather_data: 274_
# Running case number: 113 grid: 113
# Debug: Reservoir name inside parse_psm3: 248_
# Debug: Reservoir name inside download_weather_data: 248_
# Running case number: 114 grid: 114
# Debug: Reservoir name inside parse_psm3: 161_
# Debug: Reservoir name inside download_weather_data: 161_
# Running case number: 115 grid: 115
# Debug: Reservoir name inside parse_psm3: 250_
# Debug: Reservoir name inside download_weather_data: 250_
# Running case number: 116 grid: 116
# Debug: Reservoir name inside parse_psm3: 319_
# Debug: Reservoir name inside download_weather_data: 319_
# Running case number: 117 grid: 117
# Debug: Reservoir name inside parse_psm3: 97_
# Debug: Reservoir name inside download_weather_data: 97_
# Running case number: 118 grid: 118
# Debug: Reservoir name inside parse_psm3: 31_
# Debug: Reservoir name inside download_weather_data: 31_
# Running case number: 119 grid: 119
# Debug: Reservoir name inside parse_psm3: 36_
# Debug: Reservoir name inside download_weather_data: 36_
# Running case number: 120 grid: 120
# Debug: Reservoir name inside parse_psm3: 135_
# Debug: Reservoir name inside download_weather_data: 135_
# Running case number: 121 grid: 121
# Debug: Reservoir name inside parse_psm3: 95_
# Debug: Reservoir name inside download_weather_data: 95_
# Running case number: 122 grid: 122
# Debug: Reservoir name inside parse_psm3: 130_
# Debug: Reservoir name inside download_weather_data: 130_
# Running case number: 123 grid: 123
# Debug: Reservoir name inside parse_psm3: 351_
# Debug: Reservoir name inside download_weather_data: 351_
# Running case number: 124 grid: 124
# Debug: Reservoir name inside parse_psm3: 106_
# Debug: Reservoir name inside download_weather_data: 106_
# Running case number: 125 grid: 125
# Debug: Reservoir name inside parse_psm3: 33_
# Debug: Reservoir name inside download_weather_data: 33_
# Running case number: 126 grid: 126
# Debug: Reservoir name inside parse_psm3: 96_
# Debug: Reservoir name inside download_weather_data: 96_
# Running case number: 127 grid: 127
# Debug: Reservoir name inside parse_psm3: 133_
# Debug: Reservoir name inside download_weather_data: 133_
# Running case number: 128 grid: 128
# Debug: Reservoir name inside parse_psm3: 163_
# Debug: Reservoir name inside download_weather_data: 163_
# Running case number: 129 grid: 129
# Debug: Reservoir name inside parse_psm3: 207_
# Debug: Reservoir name inside download_weather_data: 207_
# Running case number: 130 grid: 130
# Debug: Reservoir name inside parse_psm3: 320_
# Debug: Reservoir name inside download_weather_data: 320_
# Running case number: 131 grid: 131
# Debug: Reservoir name inside parse_psm3: 428_
# Debug: Reservoir name inside download_weather_data: 428_
# Running case number: 132 grid: 132
# Debug: Reservoir name inside parse_psm3: 321_
# Debug: Reservoir name inside download_weather_data: 321_
# Running case number: 133 grid: 133
# Debug: Reservoir name inside parse_psm3: 205_
# Debug: Reservoir name inside download_weather_data: 205_
# Running case number: 134 grid: 134
# Debug: Reservoir name inside parse_psm3: 350_
# Debug: Reservoir name inside download_weather_data: 350_
# Running case number: 135 grid: 135
# Debug: Reservoir name inside parse_psm3: 352_
# Debug: Reservoir name inside download_weather_data: 352_
# Running case number: 136 grid: 136
# Debug: Reservoir name inside parse_psm3: 363_
# Debug: Reservoir name inside download_weather_data: 363_
# Running case number: 137 grid: 137
# Debug: Reservoir name inside parse_psm3: 167_
# Debug: Reservoir name inside download_weather_data: 167_
# Running case number: 138 grid: 138
# Debug: Reservoir name inside parse_psm3: 399_
# Debug: Reservoir name inside download_weather_data: 399_
# Running case number: 139 grid: 139
# Debug: Reservoir name inside parse_psm3: 289_
# Debug: Reservoir name inside download_weather_data: 289_
# Running case number: 140 grid: 140
# Debug: Reservoir name inside parse_psm3: 147_
# Debug: Reservoir name inside download_weather_data: 147_
# Running case number: 141 grid: 141
# Debug: Reservoir name inside parse_psm3: 353_
# Debug: Reservoir name inside download_weather_data: 353_
# Running case number: 142 grid: 142
# Debug: Reservoir name inside parse_psm3: 277_
# Debug: Reservoir name inside download_weather_data: 277_
# Running case number: 143 grid: 143
# Debug: Reservoir name inside parse_psm3: 425_
# Debug: Reservoir name inside download_weather_data: 425_
# Running case number: 144 grid: 144
# Debug: Reservoir name inside parse_psm3: 80_
# Debug: Reservoir name inside download_weather_data: 80_
# Running case number: 145 grid: 145
# Debug: Reservoir name inside parse_psm3: 111_
# Debug: Reservoir name inside download_weather_data: 111_
# Running case number: 146 grid: 146
# Debug: Reservoir name inside parse_psm3: 346_
# Debug: Reservoir name inside download_weather_data: 346_
# Running case number: 147 grid: 147
# Debug: Reservoir name inside parse_psm3: 217_
# Debug: Reservoir name inside download_weather_data: 217_
# Running case number: 148 grid: 148
# Debug: Reservoir name inside parse_psm3: 349_
# Debug: Reservoir name inside download_weather_data: 349_
# Running case number: 149 grid: 149
# Debug: Reservoir name inside parse_psm3: 72_
# Debug: Reservoir name inside download_weather_data: 72_
# Running case number: 150 grid: 150
# Debug: Reservoir name inside parse_psm3: 83_
# Debug: Reservoir name inside download_weather_data: 83_
# Running case number: 151 grid: 151
# Debug: Reservoir name inside parse_psm3: 281_
# Debug: Reservoir name inside download_weather_data: 281_
# Running case number: 152 grid: 152
# Debug: Reservoir name inside parse_psm3: 263_
# Debug: Reservoir name inside download_weather_data: 263_
# Running case number: 153 grid: 153
# Debug: Reservoir name inside parse_psm3: 120_
# Debug: Reservoir name inside download_weather_data: 120_
# Running case number: 154 grid: 154
# Debug: Reservoir name inside parse_psm3: 282_
# Debug: Reservoir name inside download_weather_data: 282_
# Running case number: 155 grid: 155
# Debug: Reservoir name inside parse_psm3: 78_
# Debug: Reservoir name inside download_weather_data: 78_
# Running case number: 156 grid: 156
# Debug: Reservoir name inside parse_psm3: 126_
# Debug: Reservoir name inside download_weather_data: 126_
# Running case number: 157 grid: 157
# Debug: Reservoir name inside parse_psm3: 409_
# Debug: Reservoir name inside download_weather_data: 409_
# Running case number: 158 grid: 158
# Debug: Reservoir name inside parse_psm3: 139_
# Debug: Reservoir name inside download_weather_data: 139_
# Running case number: 159 grid: 159
# Debug: Reservoir name inside parse_psm3: 89_
# Debug: Reservoir name inside download_weather_data: 89_
# Running case number: 160 grid: 160
# Debug: Reservoir name inside parse_psm3: 271_
# Debug: Reservoir name inside download_weather_data: 271_
# Running case number: 161 grid: 161
# Debug: Reservoir name inside parse_psm3: 128_
# Debug: Reservoir name inside download_weather_data: 128_
# Running case number: 162 grid: 162
# Debug: Reservoir name inside parse_psm3: 265_
# Debug: Reservoir name inside download_weather_data: 265_
# Running case number: 163 grid: 163
# Debug: Reservoir name inside parse_psm3: 125_
# Debug: Reservoir name inside download_weather_data: 125_
# Running case number: 164 grid: 164
# Debug: Reservoir name inside parse_psm3: 76_
# Debug: Reservoir name inside download_weather_data: 76_
# Running case number: 165 grid: 165
# Debug: Reservoir name inside parse_psm3: 129_
# Debug: Reservoir name inside download_weather_data: 129_
# Running case number: 166 grid: 166
# Debug: Reservoir name inside parse_psm3: 436_
# Debug: Reservoir name inside download_weather_data: 436_
# Running case number: 167 grid: 167
# Debug: Reservoir name inside parse_psm3: 432_
# Debug: Reservoir name inside download_weather_data: 432_
# Running case number: 168 grid: 168
# Debug: Reservoir name inside parse_psm3: 286_
# Debug: Reservoir name inside download_weather_data: 286_
# Running case number: 169 grid: 169
# Debug: Reservoir name inside parse_psm3: 332_
# Debug: Reservoir name inside download_weather_data: 332_
# Running case number: 170 grid: 170
# Debug: Reservoir name inside parse_psm3: 69_
# Debug: Reservoir name inside download_weather_data: 69_
# Running case number: 171 grid: 171
# Debug: Reservoir name inside parse_psm3: 273_
# Debug: Reservoir name inside download_weather_data: 273_
# Running case number: 172 grid: 172
# Debug: Reservoir name inside parse_psm3: 311_
# Debug: Reservoir name inside download_weather_data: 311_
# Running case number: 173 grid: 173
# Debug: Reservoir name inside parse_psm3: 331_
# Debug: Reservoir name inside download_weather_data: 331_
# Running case number: 174 grid: 174
# Debug: Reservoir name inside parse_psm3: 356_
# Debug: Reservoir name inside download_weather_data: 356_
# Running case number: 175 grid: 175
# Debug: Reservoir name inside parse_psm3: 124_
# Debug: Reservoir name inside download_weather_data: 124_
# Running case number: 176 grid: 176
# Debug: Reservoir name inside parse_psm3: 415_
# Debug: Reservoir name inside download_weather_data: 415_
# Running case number: 177 grid: 177
# Debug: Reservoir name inside parse_psm3: 315_
# Debug: Reservoir name inside download_weather_data: 315_
# Running case number: 178 grid: 178
# Debug: Reservoir name inside parse_psm3: 309_
# Debug: Reservoir name inside download_weather_data: 309_
# Running case number: 179 grid: 179
# Debug: Reservoir name inside parse_psm3: 269_
# Debug: Reservoir name inside download_weather_data: 269_
# Running case number: 180 grid: 180
# Debug: Reservoir name inside parse_psm3: 291_
# Debug: Reservoir name inside download_weather_data: 291_
# Running case number: 181 grid: 181
# Debug: Reservoir name inside parse_psm3: 215_
# Debug: Reservoir name inside download_weather_data: 215_
# Running case number: 182 grid: 182
# Debug: Reservoir name inside parse_psm3: 121_
# Debug: Reservoir name inside download_weather_data: 121_
# Running case number: 183 grid: 183
# Debug: Reservoir name inside parse_psm3: 165_
# Debug: Reservoir name inside download_weather_data: 165_
# Running case number: 184 grid: 184
# Debug: Reservoir name inside parse_psm3: 127_
# Debug: Reservoir name inside download_weather_data: 127_
# Running case number: 185 grid: 185
# Debug: Reservoir name inside parse_psm3: 330_
# Debug: Reservoir name inside download_weather_data: 330_
# Running case number: 186 grid: 186
# Debug: Reservoir name inside parse_psm3: 166_
# Debug: Reservoir name inside download_weather_data: 166_
# Running case number: 187 grid: 187
# Debug: Reservoir name inside parse_psm3: 49_
# Debug: Reservoir name inside download_weather_data: 49_
# Running case number: 188 grid: 188
# Debug: Reservoir name inside parse_psm3: 58_
# Debug: Reservoir name inside download_weather_data: 58_
# Running case number: 189 grid: 189
# Debug: Reservoir name inside parse_psm3: 60_
# Debug: Reservoir name inside download_weather_data: 60_
# Running case number: 190 grid: 190
# Debug: Reservoir name inside parse_psm3: 30_
# Debug: Reservoir name inside download_weather_data: 30_
# Running case number: 191 grid: 191
# Debug: Reservoir name inside parse_psm3: 335_
# Debug: Reservoir name inside download_weather_data: 335_
# Running case number: 192 grid: 192
# Debug: Reservoir name inside parse_psm3: 348_
# Debug: Reservoir name inside download_weather_data: 348_
# Running case number: 193 grid: 193
# Debug: Reservoir name inside parse_psm3: 156_
# Debug: Reservoir name inside download_weather_data: 156_
# Running case number: 194 grid: 194
# Debug: Reservoir name inside parse_psm3: 333_
# Debug: Reservoir name inside download_weather_data: 333_
# Running case number: 195 grid: 195
# Debug: Reservoir name inside parse_psm3: 338_
# Debug: Reservoir name inside download_weather_data: 338_
# Running case number: 196 grid: 196
# Debug: Reservoir name inside parse_psm3: 45_
# Debug: Reservoir name inside download_weather_data: 45_
# Running case number: 197 grid: 197
# Debug: Reservoir name inside parse_psm3: 423_
# Debug: Reservoir name inside download_weather_data: 423_
# Running case number: 198 grid: 198
# Debug: Reservoir name inside parse_psm3: 191_
# Debug: Reservoir name inside download_weather_data: 191_
# Running case number: 199 grid: 199
# Debug: Reservoir name inside parse_psm3: 272_
# Debug: Reservoir name inside download_weather_data: 272_
# Running case number: 200 grid: 200
# Debug: Reservoir name inside parse_psm3: 339_
# Debug: Reservoir name inside download_weather_data: 339_
# Running case number: 201 grid: 201
# Debug: Reservoir name inside parse_psm3: 200_
# Debug: Reservoir name inside download_weather_data: 200_
# Running case number: 202 grid: 202
# Debug: Reservoir name inside parse_psm3: 32_
# Debug: Reservoir name inside download_weather_data: 32_
# Running case number: 203 grid: 203
# Debug: Reservoir name inside parse_psm3: 251_
# Debug: Reservoir name inside download_weather_data: 251_
# Running case number: 204 grid: 204
# Debug: Reservoir name inside parse_psm3: 104_
# Debug: Reservoir name inside download_weather_data: 104_
# Running case number: 205 grid: 205
# Debug: Reservoir name inside parse_psm3: 259_
# Debug: Reservoir name inside download_weather_data: 259_
# Running case number: 206 grid: 206
# Debug: Reservoir name inside parse_psm3: 345_
# Debug: Reservoir name inside download_weather_data: 345_
# Running case number: 207 grid: 207
# Debug: Reservoir name inside parse_psm3: 35_
# Debug: Reservoir name inside download_weather_data: 35_
# Running case number: 208 grid: 208
# Debug: Reservoir name inside parse_psm3: 155_
# Debug: Reservoir name inside download_weather_data: 155_
# Running case number: 209 grid: 209
# Debug: Reservoir name inside parse_psm3: 336_
# Debug: Reservoir name inside download_weather_data: 336_
# Running case number: 210 grid: 210
# Debug: Reservoir name inside parse_psm3: 267_
# Debug: Reservoir name inside download_weather_data: 267_
# Running case number: 211 grid: 211
# Debug: Reservoir name inside parse_psm3: 275_
# Debug: Reservoir name inside download_weather_data: 275_
# Running case number: 212 grid: 212
# Debug: Reservoir name inside parse_psm3: 304_
# Debug: Reservoir name inside download_weather_data: 304_
# Running case number: 213 grid: 213
# Debug: Reservoir name inside parse_psm3: 334_
# Debug: Reservoir name inside download_weather_data: 334_
# Running case number: 214 grid: 214
# Debug: Reservoir name inside parse_psm3: 51_
# Debug: Reservoir name inside download_weather_data: 51_
# Running case number: 215 grid: 215
# Debug: Reservoir name inside parse_psm3: 39_
# Debug: Reservoir name inside download_weather_data: 39_
# Running case number: 216 grid: 216
# Debug: Reservoir name inside parse_psm3: 407_
# Debug: Reservoir name inside download_weather_data: 407_
# Running case number: 217 grid: 217
# Debug: Reservoir name inside parse_psm3: 266_
# Debug: Reservoir name inside download_weather_data: 266_
# Running case number: 218 grid: 218
# Debug: Reservoir name inside parse_psm3: 75_
# Debug: Reservoir name inside download_weather_data: 75_
# Running case number: 219 grid: 219
# Debug: Reservoir name inside parse_psm3: 146_
# Debug: Reservoir name inside download_weather_data: 146_
# Running case number: 220 grid: 220
# Debug: Reservoir name inside parse_psm3: 400_
# Debug: Reservoir name inside download_weather_data: 400_
# Running case number: 221 grid: 221
# Debug: Reservoir name inside parse_psm3: 268_
# Debug: Reservoir name inside download_weather_data: 268_
# Running case number: 222 grid: 222
# Debug: Reservoir name inside parse_psm3: 313_
# Debug: Reservoir name inside download_weather_data: 313_
# Running case number: 223 grid: 223
# Debug: Reservoir name inside parse_psm3: 344_
# Debug: Reservoir name inside download_weather_data: 344_
# Running case number: 224 grid: 224
# Debug: Reservoir name inside parse_psm3: 154_
# Debug: Reservoir name inside download_weather_data: 154_
# Running case number: 225 grid: 225
# Debug: Reservoir name inside parse_psm3: 206_
# Debug: Reservoir name inside download_weather_data: 206_
# Running case number: 226 grid: 226
# Debug: Reservoir name inside parse_psm3: 383_
# Debug: Reservoir name inside download_weather_data: 383_
# Running case number: 227 grid: 227
# Debug: Reservoir name inside parse_psm3: 103_
# Debug: Reservoir name inside download_weather_data: 103_
# Running case number: 228 grid: 228
# Debug: Reservoir name inside parse_psm3: 416_
# Debug: Reservoir name inside download_weather_data: 416_
# Running case number: 229 grid: 229
# Debug: Reservoir name inside parse_psm3: 288_
# Debug: Reservoir name inside download_weather_data: 288_
# Running case number: 230 grid: 230
# Debug: Reservoir name inside parse_psm3: 208_
# Debug: Reservoir name inside download_weather_data: 208_
# Running case number: 231 grid: 231
# Debug: Reservoir name inside parse_psm3: 433_
# Debug: Reservoir name inside download_weather_data: 433_
# Running case number: 232 grid: 232
# Debug: Reservoir name inside parse_psm3: 192_
# Debug: Reservoir name inside download_weather_data: 192_
# Running case number: 233 grid: 233
# Debug: Reservoir name inside parse_psm3: 73_
# Debug: Reservoir name inside download_weather_data: 73_
# Running case number: 234 grid: 234
# Debug: Reservoir name inside parse_psm3: 260_
# Debug: Reservoir name inside download_weather_data: 260_
# Running case number: 235 grid: 235
# Debug: Reservoir name inside parse_psm3: 391_
# Debug: Reservoir name inside download_weather_data: 391_
# Running case number: 236 grid: 236
# Debug: Reservoir name inside parse_psm3: 408_
# Debug: Reservoir name inside download_weather_data: 408_
# Running case number: 237 grid: 237
# Debug: Reservoir name inside parse_psm3: 64_
# Debug: Reservoir name inside download_weather_data: 64_
# Running case number: 238 grid: 238
# Debug: Reservoir name inside parse_psm3: 424_
# Debug: Reservoir name inside download_weather_data: 424_
# Running case number: 239 grid: 239
# Debug: Reservoir name inside parse_psm3: 294_
# Debug: Reservoir name inside download_weather_data: 294_
# Running case number: 240 grid: 240
# Debug: Reservoir name inside parse_psm3: 50_
# Debug: Reservoir name inside download_weather_data: 50_
# Running case number: 241 grid: 241
# Debug: Reservoir name inside parse_psm3: 283_
# Debug: Reservoir name inside download_weather_data: 283_
# Running case number: 242 grid: 242
# Debug: Reservoir name inside parse_psm3: 26_
# Debug: Reservoir name inside download_weather_data: 26_
# Running case number: 243 grid: 243
# Debug: Reservoir name inside parse_psm3: 258_
# Debug: Reservoir name inside download_weather_data: 258_
# Running case number: 244 grid: 244
# Debug: Reservoir name inside parse_psm3: 151_
# Debug: Reservoir name inside download_weather_data: 151_
# Running case number: 245 grid: 245
# Debug: Reservoir name inside parse_psm3: 67_
# Debug: Reservoir name inside download_weather_data: 67_
# Running case number: 246 grid: 246
# Debug: Reservoir name inside parse_psm3: 361_
# Debug: Reservoir name inside download_weather_data: 361_
# Running case number: 247 grid: 247
# Debug: Reservoir name inside parse_psm3: 152_
# Debug: Reservoir name inside download_weather_data: 152_
# Running case number: 248 grid: 248
# Debug: Reservoir name inside parse_psm3: 403_
# Debug: Reservoir name inside download_weather_data: 403_
# Running case number: 249 grid: 249
# Debug: Reservoir name inside parse_psm3: 414_
# Debug: Reservoir name inside download_weather_data: 414_
# Running case number: 250 grid: 250
# Debug: Reservoir name inside parse_psm3: 2_
# Debug: Reservoir name inside download_weather_data: 2_
# Running case number: 251 grid: 251
# Debug: Reservoir name inside parse_psm3: 1_
# Debug: Reservoir name inside download_weather_data: 1_
# Running case number: 252 grid: 252
# Debug: Reservoir name inside parse_psm3: 107_
# Debug: Reservoir name inside download_weather_data: 107_
# Running case number: 253 grid: 253
# Debug: Reservoir name inside parse_psm3: 212_
# Debug: Reservoir name inside download_weather_data: 212_
# Running case number: 254 grid: 254
# Debug: Reservoir name inside parse_psm3: 405_
# Debug: Reservoir name inside download_weather_data: 405_
# Running case number: 255 grid: 255
# Debug: Reservoir name inside parse_psm3: 171_
# Debug: Reservoir name inside download_weather_data: 171_
# Running case number: 256 grid: 256
# Debug: Reservoir name inside parse_psm3: 210_
# Debug: Reservoir name inside download_weather_data: 210_
# Running case number: 257 grid: 257
# Debug: Reservoir name inside parse_psm3: 293_
# Debug: Reservoir name inside download_weather_data: 293_
# Running case number: 258 grid: 258
# Debug: Reservoir name inside parse_psm3: 395_
# Debug: Reservoir name inside download_weather_data: 395_
# Running case number: 259 grid: 259
# Debug: Reservoir name inside parse_psm3: 374_
# Debug: Reservoir name inside download_weather_data: 374_
# Running case number: 260 grid: 260
# Debug: Reservoir name inside parse_psm3: 389_
# Debug: Reservoir name inside download_weather_data: 389_
# Running case number: 261 grid: 261
# Debug: Reservoir name inside parse_psm3: 431_
# Debug: Reservoir name inside download_weather_data: 431_
# Running case number: 262 grid: 262
# Debug: Reservoir name inside parse_psm3: 402_
# Debug: Reservoir name inside download_weather_data: 402_
# Running case number: 263 grid: 263
# Debug: Reservoir name inside parse_psm3: 23_
# Debug: Reservoir name inside download_weather_data: 23_
# Running case number: 264 grid: 264
# Debug: Reservoir name inside parse_psm3: 318_
# Debug: Reservoir name inside download_weather_data: 318_
# Running case number: 265 grid: 265
# Debug: Reservoir name inside parse_psm3: 370_
# Debug: Reservoir name inside download_weather_data: 370_
# Running case number: 266 grid: 266
# Debug: Reservoir name inside parse_psm3: 287_
# Debug: Reservoir name inside download_weather_data: 287_
# Running case number: 267 grid: 267
# Debug: Reservoir name inside parse_psm3: 327_
# Debug: Reservoir name inside download_weather_data: 327_
# Running case number: 268 grid: 268
# Debug: Reservoir name inside parse_psm3: 82_
# Debug: Reservoir name inside download_weather_data: 82_
# Running case number: 269 grid: 269
# Debug: Reservoir name inside parse_psm3: 372_
# Debug: Reservoir name inside download_weather_data: 372_
# Running case number: 270 grid: 270
# Debug: Reservoir name inside parse_psm3: 308_
# Debug: Reservoir name inside download_weather_data: 308_
# Running case number: 271 grid: 271
# Debug: Reservoir name inside parse_psm3: 406_
# Debug: Reservoir name inside download_weather_data: 406_
# Running case number: 272 grid: 272
# Debug: Reservoir name inside parse_psm3: 81_
# Debug: Reservoir name inside download_weather_data: 81_
# Running case number: 273 grid: 273
# Debug: Reservoir name inside parse_psm3: 211_
# Debug: Reservoir name inside download_weather_data: 211_
# Running case number: 274 grid: 274
# Debug: Reservoir name inside parse_psm3: 44_
# Debug: Reservoir name inside download_weather_data: 44_
# Running case number: 275 grid: 275
# Debug: Reservoir name inside parse_psm3: 262_
# Debug: Reservoir name inside download_weather_data: 262_
# Running case number: 276 grid: 276
# Debug: Reservoir name inside parse_psm3: 358_
# Debug: Reservoir name inside download_weather_data: 358_
# Running case number: 277 grid: 277
# Debug: Reservoir name inside parse_psm3: 172_
# Debug: Reservoir name inside download_weather_data: 172_
# Running case number: 278 grid: 278
# Debug: Reservoir name inside parse_psm3: 422_
# Debug: Reservoir name inside download_weather_data: 422_
# Running case number: 279 grid: 279
# Debug: Reservoir name inside parse_psm3: 355_
# Debug: Reservoir name inside download_weather_data: 355_
# Running case number: 280 grid: 280
# Debug: Reservoir name inside parse_psm3: 140_
# Debug: Reservoir name inside download_weather_data: 140_
# Running case number: 281 grid: 281
# Debug: Reservoir name inside parse_psm3: 141_
# Debug: Reservoir name inside download_weather_data: 141_
# Running case number: 282 grid: 282
# Debug: Reservoir name inside parse_psm3: 142_
# Debug: Reservoir name inside download_weather_data: 142_
# Running case number: 283 grid: 283
# Debug: Reservoir name inside parse_psm3: 143_
# Debug: Reservoir name inside download_weather_data: 143_
# Running case number: 284 grid: 284
# Debug: Reservoir name inside parse_psm3: 393_
# Debug: Reservoir name inside download_weather_data: 393_
# Running case number: 285 grid: 285
# Debug: Reservoir name inside parse_psm3: 3_
# Debug: Reservoir name inside download_weather_data: 3_
# Running case number: 286 grid: 286
# Debug: Reservoir name inside parse_psm3: 38_
# Debug: Reservoir name inside download_weather_data: 38_
# Running case number: 287 grid: 287
# Debug: Reservoir name inside parse_psm3: 376_
# Debug: Reservoir name inside download_weather_data: 376_
# Running case number: 288 grid: 288
# Debug: Reservoir name inside parse_psm3: 401_
# Debug: Reservoir name inside download_weather_data: 401_
# Running case number: 289 grid: 289
# Debug: Reservoir name inside parse_psm3: 157_
# Debug: Reservoir name inside download_weather_data: 157_
# Running case number: 290 grid: 290
# Debug: Reservoir name inside parse_psm3: 324_
# Debug: Reservoir name inside download_weather_data: 324_
# Running case number: 291 grid: 291
# Debug: Reservoir name inside parse_psm3: 322_
# Debug: Reservoir name inside download_weather_data: 322_
# Running case number: 292 grid: 292
# Debug: Reservoir name inside parse_psm3: 418_
# Debug: Reservoir name inside download_weather_data: 418_
# Running case number: 293 grid: 293
# Debug: Reservoir name inside parse_psm3: 56_
# Debug: Reservoir name inside download_weather_data: 56_
# Running case number: 294 grid: 294
# Debug: Reservoir name inside parse_psm3: 307_
# Debug: Reservoir name inside download_weather_data: 307_
# Running case number: 295 grid: 295
# Debug: Reservoir name inside parse_psm3: 404_
# Debug: Reservoir name inside download_weather_data: 404_
# Running case number: 296 grid: 296
# Debug: Reservoir name inside parse_psm3: 54_
# Debug: Reservoir name inside download_weather_data: 54_
# Running case number: 297 grid: 297
# Debug: Reservoir name inside parse_psm3: 195_
# Debug: Reservoir name inside download_weather_data: 195_
# Running case number: 298 grid: 298
# Debug: Reservoir name inside parse_psm3: 396_
# Debug: Reservoir name inside download_weather_data: 396_
# Running case number: 299 grid: 299
# Debug: Reservoir name inside parse_psm3: 198_
# Debug: Reservoir name inside download_weather_data: 198_
# ...
# Running case number: 368 grid: 368
# Debug: Reservoir name inside parse_psm3: 108_
# Debug: Reservoir name inside download_weather_data: 108_
# Running case number: 369 grid: 369
# Debug: Reservoir name inside parse_psm3: 284_
# Debug: Reservoir name inside download_weather_data: 284_
# Running case number: 370 grid: 370
# Debug: Reservoir name inside parse_psm3: 52_
# Debug: Reservoir name inside download_weather_data: 52_
# Running case number: 371 grid: 371
# Debug: Reservoir name inside parse_psm3: 371_
# Debug: Reservoir name inside download_weather_data: 371_
# Running case number: 372 grid: 372
# Debug: Reservoir name inside parse_psm3: 377_
# Debug: Reservoir name inside download_weather_data: 377_
# Running case number: 373 grid: 373
# Debug: Reservoir name inside parse_psm3: 47_
# Debug: Reservoir name inside download_weather_data: 47_
# Running case number: 374 grid: 374
# Debug: Reservoir name inside parse_psm3: 176_
# Debug: Reservoir name inside download_weather_data: 176_
# Running case number: 375 grid: 375
# Debug: Reservoir name inside parse_psm3: 187_
# Debug: Reservoir name inside download_weather_data: 187_
# Running case number: 376 grid: 376
# Debug: Reservoir name inside parse_psm3: 412_
# Debug: Reservoir name inside download_weather_data: 412_
# Running case number: 377 grid: 377
# Debug: Reservoir name inside parse_psm3: 386_
# Debug: Reservoir name inside download_weather_data: 386_
# Running case number: 378 grid: 378
# Debug: Reservoir name inside parse_psm3: 100_
# Debug: Reservoir name inside download_weather_data: 100_
# Running case number: 379 grid: 379
# Debug: Reservoir name inside parse_psm3: 182_
# Debug: Reservoir name inside download_weather_data: 182_
# Running case number: 380 grid: 380
# Debug: Reservoir name inside parse_psm3: 90_
# Debug: Reservoir name inside download_weather_data: 90_
# Running case number: 381 grid: 381
# Debug: Reservoir name inside parse_psm3: 185_
# Debug: Reservoir name inside download_weather_data: 185_
# Running case number: 382 grid: 382
# Debug: Reservoir name inside parse_psm3: 434_
# Debug: Reservoir name inside download_weather_data: 434_
# Running case number: 383 grid: 383
# Debug: Reservoir name inside parse_psm3: 285_
# Debug: Reservoir name inside download_weather_data: 285_
# Running case number: 384 grid: 384
# Debug: Reservoir name inside parse_psm3: 112_
# Debug: Reservoir name inside download_weather_data: 112_
# Running case number: 385 grid: 385
# Debug: Reservoir name inside parse_psm3: 63_
# Debug: Reservoir name inside download_weather_data: 63_
# Running case number: 386 grid: 386
# Debug: Reservoir name inside parse_psm3: 183_
# Debug: Reservoir name inside download_weather_data: 183_
# Running case number: 387 grid: 387
# Debug: Reservoir name inside parse_psm3: 253_
# Debug: Reservoir name inside download_weather_data: 253_
# Running case number: 388 grid: 388
# Debug: Reservoir name inside parse_psm3: 305_
# Debug: Reservoir name inside download_weather_data: 305_
# Running case number: 389 grid: 389
# Debug: Reservoir name inside parse_psm3: 25_
# Debug: Reservoir name inside download_weather_data: 25_
# Running case number: 390 grid: 390
# Debug: Reservoir name inside parse_psm3: 342_
# Debug: Reservoir name inside download_weather_data: 342_
# Running case number: 391 grid: 391
# Debug: Reservoir name inside parse_psm3: 343_
# Debug: Reservoir name inside download_weather_data: 343_
# Running case number: 392 grid: 392
# Debug: Reservoir name inside parse_psm3: 410_
# Debug: Reservoir name inside download_weather_data: 410_
# Running case number: 393 grid: 393
# Debug: Reservoir name inside parse_psm3: 59_
# Debug: Reservoir name inside download_weather_data: 59_
# Running case number: 394 grid: 394
# Debug: Reservoir name inside parse_psm3: 144_
# Debug: Reservoir name inside download_weather_data: 144_
# Running case number: 395 grid: 395
# Debug: Reservoir name inside parse_psm3: 57_
# Debug: Reservoir name inside download_weather_data: 57_
# Running case number: 396 grid: 396
# Debug: Reservoir name inside parse_psm3: 99_
# Debug: Reservoir name inside download_weather_data: 99_
# Running case number: 397 grid: 397
# Debug: Reservoir name inside parse_psm3: 379_
# Debug: Reservoir name inside download_weather_data: 379_
# Running case number: 398 grid: 398
# Debug: Reservoir name inside parse_psm3: 290_
# Debug: Reservoir name inside download_weather_data: 290_
# Running case number: 399 grid: 399
# Debug: Reservoir name inside parse_psm3: 375_
# Debug: Reservoir name inside download_weather_data: 375_
# Running case number: 400 grid: 400
# Debug: Reservoir name inside parse_psm3: 37_
# Debug: Reservoir name inside download_weather_data: 37_
# Running case number: 401 grid: 401
# Debug: Reservoir name inside parse_psm3: 153_
# Debug: Reservoir name inside download_weather_data: 153_
# Running case number: 402 grid: 402
# Debug: Reservoir name inside parse_psm3: 394_
# Debug: Reservoir name inside download_weather_data: 394_
# Running case number: 403 grid: 403
# Debug: Reservoir name inside parse_psm3: 119_
# Debug: Reservoir name inside download_weather_data: 119_
# Running case number: 404 grid: 404
# Debug: Reservoir name inside parse_psm3: 193_
# Debug: Reservoir name inside download_weather_data: 193_
# Running case number: 405 grid: 405
# Debug: Reservoir name inside parse_psm3: 387_
# Debug: Reservoir name inside download_weather_data: 387_
# Running case number: 406 grid: 406
# Debug: Reservoir name inside parse_psm3: 87_
# Debug: Reservoir name inside download_weather_data: 87_
# Running case number: 407 grid: 407
# Debug: Reservoir name inside parse_psm3: 91_
# Debug: Reservoir name inside download_weather_data: 91_
# Running case number: 408 grid: 408
# Debug: Reservoir name inside parse_psm3: 184_
# Debug: Reservoir name inside download_weather_data: 184_
# Running case number: 409 grid: 409
# Debug: Reservoir name inside parse_psm3: 413_
# Debug: Reservoir name inside download_weather_data: 413_
# Running case number: 410 grid: 410
# Debug: Reservoir name inside parse_psm3: 364_
# Debug: Reservoir name inside download_weather_data: 364_
# Running case number: 411 grid: 411
# Debug: Reservoir name inside parse_psm3: 365_
# Debug: Reservoir name inside download_weather_data: 365_
# Running case number: 412 grid: 412
# Debug: Reservoir name inside parse_psm3: 366_
# Debug: Reservoir name inside download_weather_data: 366_
# Running case number: 413 grid: 413
# Debug: Reservoir name inside parse_psm3: 367_
# Debug: Reservoir name inside download_weather_data: 367_
# Running case number: 414 grid: 414
# Debug: Reservoir name inside parse_psm3: 397_
# Debug: Reservoir name inside download_weather_data: 397_
# Running case number: 415 grid: 415
# Debug: Reservoir name inside parse_psm3: 186_
# Debug: Reservoir name inside download_weather_data: 186_
# Running case number: 416 grid: 416
# Debug: Reservoir name inside parse_psm3: 92_
# Debug: Reservoir name inside download_weather_data: 92_
# Running case number: 417 grid: 417
# Debug: Reservoir name inside parse_psm3: 179_
# Debug: Reservoir name inside download_weather_data: 179_
# Running case number: 418 grid: 418
# Debug: Reservoir name inside parse_psm3: 323_
# Debug: Reservoir name inside download_weather_data: 323_
# Running case number: 419 grid: 419
# Debug: Reservoir name inside parse_psm3: 385_
# Debug: Reservoir name inside download_weather_data: 385_
# Running case number: 420 grid: 420
# Debug: Reservoir name inside parse_psm3: 65_
# Debug: Reservoir name inside download_weather_data: 65_
# Running case number: 421 grid: 421
# Debug: Reservoir name inside parse_psm3: 66_
# Debug: Reservoir name inside download_weather_data: 66_
# Running case number: 422 grid: 422
# Debug: Reservoir name inside parse_psm3: 109_
# Debug: Reservoir name inside download_weather_data: 109_
# Running case number: 423 grid: 423
# Debug: Reservoir name inside parse_psm3: 178_
# Debug: Reservoir name inside download_weather_data: 178_
# Running case number: 424 grid: 424
# Debug: Reservoir name inside parse_psm3: 278_
# Debug: Reservoir name inside download_weather_data: 278_
# Running case number: 425 grid: 425
# Debug: Reservoir name inside parse_psm3: 46_
# Debug: Reservoir name inside download_weather_data: 46_
# Running case number: 426 grid: 426
# Debug: Reservoir name inside parse_psm3: 164_
# Debug: Reservoir name inside download_weather_data: 164_
# Running case number: 427 grid: 427
# Debug: Reservoir name inside parse_psm3: 177_
# Debug: Reservoir name inside download_weather_data: 177_
# Running case number: 428 grid: 428
# Debug: Reservoir name inside parse_psm3: 94_
# Debug: Reservoir name inside download_weather_data: 94_
# Running case number: 429 grid: 429
# Debug: Reservoir name inside parse_psm3: 102_
# Debug: Reservoir name inside download_weather_data: 102_
# Running case number: 430 grid: 430
# Debug: Reservoir name inside parse_psm3: 360_
# Debug: Reservoir name inside download_weather_data: 360_
# Running case number: 431 grid: 431
# Debug: Reservoir name inside parse_psm3: 380_
# Debug: Reservoir name inside download_weather_data: 380_
# Running case number: 432 grid: 432
# Debug: Reservoir name inside parse_psm3: 382_
# Debug: Reservoir name inside download_weather_data: 382_
# Running case number: 433 grid: 433
# Debug: Reservoir name inside parse_psm3: 384_
# Debug: Reservoir name inside download_weather_data: 384_
# Running case number: 434 grid: 434
# Debug: Reservoir name inside parse_psm3: 24_
# Debug: Reservoir name inside download_weather_data: 24_
# Running case number: 435 grid: 435
# Debug: Reservoir name inside parse_psm3: 86_
# Debug: Reservoir name inside download_weather_data: 86_
# Running case number: 436 grid: 436
# Debug: Reservoir name inside parse_psm3: 88_
# Debug: Reservoir name inside download_weather_data: 88_
# Running case number: 437 grid: 437
# Debug: Reservoir name inside parse_psm3: 202_
# Debug: Reservoir name inside download_weather_data: 202_
# Running case number: 438 grid: 438
# Debug: Reservoir name inside parse_psm3: 429_
# Debug: Reservoir name inside download_weather_data: 429_
# Running case number: 439 grid: 439
# Debug: Reservoir name inside parse_psm3: 180_
# Debug: Reservoir name inside download_weather_data: 180_
#    312_ free evaporation E mm/day  312_ free evaporation (m3)  \
# 0                        2.718523               187436.828525
# 1                        2.835023               195469.294976
# 2                        2.346894               161813.772423
# 3                        2.402364               165638.291625
# 4                        2.701729               186278.967353
#
#    312_ fcover evaporation using water savings method 3 E mm/day  \
# 0                                           2.581200
# 1                                           2.690990
# 2                                           2.215308
# 3                                           2.280513
# 4                                           2.565301
#
#    312_ fcover evaporation using water savings method 3 E m3/day  \
# 0                                      164927.774012
# 1                                      171942.838648
# 2                                      141548.779875
# 3                                      145715.132905
# 4                                      163911.839768
#
#    279_ free evaporation E mm/day  279_ free evaporation (m3)  \
# 0                        3.281207               211076.130576
# 1                        3.560053               229013.917209
# 2                        3.084595               198428.273956
# 3                        2.695599               173404.644694
# 4                        2.404699               154691.388307
#
#    279_ fcover evaporation using water savings method 3 E mm/day  \
# 0                                           3.017053
# 1                                           3.273955
# 2                                           2.835501
# 3                                           2.475979
# 4                                           2.208086
#
#    279_ fcover evaporation using water savings method 3 E m3/day  \
# 0                                      178840.401141
# 1                                      194068.614575
# 2                                      168078.642836
# 3                                      146767.411474
# 4                                      130887.621539
#
#    113_ free evaporation E mm/day  113_ free evaporation (m3)  ...  \
# 0                        2.774616               171826.648304  ...
# 1                        2.821514               174730.963793  ...
# 2                        2.553058               158106.017594  ...
# 3                        3.588738               222243.690993  ...
# 4                        3.327768               206082.298243  ...
#
#    5_ fcover evaporation using water savings method 3 E mm/day  \
# 0                                           2.037514
# 1                                           2.076740
# 2                                           1.873179
# 3                                           2.649657
# 4                                           2.461257
#
#    5_ fcover evaporation using water savings method 3 E m3/day  \
# 0                                        3761.611465
# 1                                        3834.029674
# 2                                        3458.220094
# 3                                        4891.736145
# 4                                        4543.917448
#
#    438_ free evaporation E mm/day  438_ free evaporation (m3)  \
# 0                        2.624188                 3181.879955
# 1                        3.037774                 3683.361957
# 2                        3.131869                 3797.453705
# 3                        3.943314                 4781.347092
# 4                        2.352025                 2851.877812
#
#    438_ fcover evaporation using water savings method 3 E mm/day  \
# 0                                           2.076121
# 1                                           2.447966
# 2                                           2.565150
# 3                                           3.206238
# 4                                           1.918897
#
#    438_ fcover evaporation using water savings method 3 E m3/day  \
# 0                                        1881.422387
# 1                                        2218.396080
# 2                                        2324.590649
# 3                                        2905.557380
# 4                                        1738.943659
#
#    123_ free evaporation E mm/day  123_ free evaporation (m3)  \
# 0                        2.429210                 2739.881461
# 1                        2.227960                 2512.894321
# 2                        2.545503                 2871.047195
# 3                        2.031360                 2291.150649
# 4                        2.882773                 3251.450291
#
#    123_ fcover evaporation using water savings method 3 E mm/day  \
# 0                                           1.777888
# 1                                           1.632415
# 2                                           1.870926
# 3                                           1.480467
# 4                                           2.120025
#
#    123_ fcover evaporation using water savings method 3 E m3/day
# 0                                        1498.704051
# 1                                        1376.075081
# 2                                        1577.132572
# 3                                        1247.987905
# 4                                        1787.114860
#
# [5 rows x 116 columns]

# %%
evaporation_df.to_csv("all_southernbrazil_selectedreservoir_evaporation_v27_10pct_6km2.csv")

# %%
evaporation_df.to_csv('/content/drive/MyDrive/Colombia_nrel_all_location/daily_evaporation_colombia_v27.csv', index=False)
aggregate_evaporation_df.to_csv('/content/drive/MyDrive/Colombia_nrel_all_location/ALL_aggregate_evaporation_colombia_v27.csv', index=False)

# %% [markdown]
# ### Energy generation and economic evaluation PVlib

# %%
import io
import requests
import pandas as pd
import pvlib
from json import JSONDecodeError
import warnings
from pvlib._deprecation import pvlibDeprecationWarning
import numpy as np
import numpy_financial as npf
import datetime
import xarray as xr
import math
#import cupy as cp
from timezonefinder import TimezoneFinder
from pvlib.tools import sind
from pvlib._deprecation import warn_deprecated
from pvlib.tools import _get_sample_intervals
import scipy
import scipy.constants
import warnings
import json
import PySAM.Pvsamv1 as pvsam
from PySAM import Utilityrate5 as ur5  # Add this import statement
#import pysam
import os
from io import StringIO
import copy
import tempfile
from math import pi, cos, sin, tan, acos, sqrt, log, exp




# 'relative_humidity', 'total_precipitable_water' are not available
ATTRIBUTES = (
    'air_temperature', 'dew_point', 'dhi', 'dni', 'ghi', 'surface_albedo',
    'surface_pressure', 'wind_direction', 'wind_speed')
PVLIB_PYTHON = 'pvlib python'

# Dictionary mapping PSM3 names to pvlib names
VARIABLE_MAP = {
    'GHI': 'ghi',
    'DHI': 'dhi',
    'DNI': 'dni',
    'Clearsky GHI': 'ghi_clear',
    'Clearsky DHI': 'dhi_clear',
    'Clearsky DNI': 'dni_clear',
    'Solar Zenith Angle': 'solar_zenith',
    'Temperature': 'temp_air',
    'Relative Humidity': 'relative_humidity',
    'Dew point': 'temp_dew',
    'Pressure': 'pressure',
    'Wind Direction': 'wind_direction',
    'Wind Speed': 'wind_speed',
    'Surface Albedo': 'albedo',
    'Precipitable Water': 'precipitable_water',
}


def get_psm3(latitude, longitude, api_key, email, names='tmy', interval=60,
             attributes=ATTRIBUTES, leap_day=None, full_name=PVLIB_PYTHON,
             affiliation=PVLIB_PYTHON, map_variables=None, timeout=30, reservoir_name=""):
    # The well know text (WKT) representation of geometry notation is strict.
    # A POINT object is a string with longitude first, then the latitude, with
    # four decimals each, and exactly one space between them.
    longitude = ('%9.4f' % longitude).strip()
    latitude = ('%8.4f' % latitude).strip()
    # TODO: make format_WKT(object_type, *args) in tools.py

    # convert to string to accomodate integer years being passed in
    names = str(names)

    # convert pvlib names in attributes to psm3 convention (reverse mapping)
    # unlike psm3 columns, attributes are lower case and with underscores
    amap = {value: key.lower().replace(' ', '_') for (key, value) in
            VARIABLE_MAP.items()}
    attributes = [amap.get(a, a) for a in attributes]
    attributes = list(set(attributes))  # remove duplicate values

    if (leap_day is None) and (not names.startswith('t')):
        warnings.warn(
            'The ``get_psm3`` function will default to leap_day=True '
            'starting in pvlib 0.11.0. Specify leap_day=True '
            'to enable this behavior now, or specify leap_day=False '
            'to hide this warning.', pvlibDeprecationWarning)
        leap_day = False

    # required query-string parameters for request to PSM3 API
    params = {
        'api_key': api_key,
        'full_name': full_name,
        'email': email,
        'affiliation': affiliation,
        'reason': PVLIB_PYTHON,
        'mailing_list': 'false',
        'wkt': 'POINT(%s %s)' % (longitude, latitude),
        'names': names,
        'attributes':  ','.join(attributes),
        'leap_day': str(leap_day).lower(),
        'utc': 'false',
        'interval': interval
    }
    NSRDB_API_BASE = "https://developer.nrel.gov"
    PSM_URL1 = NSRDB_API_BASE + "/api/nsrdb/v2/solar/psm3-download.csv"
    TMY_URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/psm3-tmy-download.csv"
    PSM5MIN_URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/psm3-5min-download.csv"

    # First, check longitude conditions
    if -16 < lon < 91:
        PSM_URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/msg-iodc-download.csv"
    elif 91 < lon < 182:
        PSM_URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/himawari-download.csv"
    else:
        # Then check latitude conditions if longitude didn't match
        if lat >= -21.186575058950382:
            PSM_URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/psm3-2-2-tmy-download.csv"
        else:
            PSM_URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/full-disc-download.csv"

    # Finally, set URL based on interval and 'names' prefix
    if any(prefix in names for prefix in ('tmy', 'tgy', 'tdy')):
        URL = NSRDB_API_BASE + "/api/nsrdb/v2/solar/psm3-2-2-tmy-download.csv"
    elif interval in (5, 15):
        URL = PSM5MIN_URL
    else:
        URL = PSM_URL

    response = requests.get(URL, params=params, timeout=timeout)

    if not response.ok:
        # if the API key is rejected, then the response status will be 403
        # Forbidden, and then the error is in the content and there is no JSON
        try:
            errors = response.json()['errors']
        except JSONDecodeError:
            errors = response.content.decode('utf-8')
        raise requests.HTTPError(errors, response=response)
    # the CSV is in the response content as a UTF-8 bytestring
    # to use pandas we need to create a file buffer from the response
    fbuf = io.StringIO(response.content.decode('utf-8'))
    return parse_psm3(fbuf, map_variables, reservoir_name)



def parse_psm3(fbuf, map_variables=None, reservoir_name=""):
    # Read metadata
    metadata_fields = fbuf.readline().split(',')
    metadata_fields[-1] = metadata_fields[-1].strip()
    metadata_values = fbuf.readline().split(',')
    metadata_values[-1] = metadata_values[-1].strip()
    metadata = dict(zip(metadata_fields, metadata_values))

    # Set some metadata types to numbers
    metadata['Local Time Zone'] = int(metadata['Local Time Zone'])
    metadata['Time Zone'] = int(metadata['Time Zone'])
    metadata['Latitude'] = float(metadata['Latitude'])
    metadata['Longitude'] = float(metadata['Longitude'])
    metadata['Elevation'] = int(metadata['Elevation'])

    # Read weather data
    columns = fbuf.readline().split(',')
    columns[-1] = columns[-1].strip()
    columns = [col for col in columns if col != '']
    dtypes = dict.fromkeys(columns, float)
    dtypes.update(Year=int, Month=int, Day=int, Hour=int, Minute=int)
    dtypes['Cloud Type'] = int
    dtypes['Fill Flag'] = int
    data = pd.read_csv(
        fbuf, header=None, names=columns, usecols=columns, dtype=dtypes,
        delimiter=',', lineterminator='\n')

    # Convert date vector to datetime
    dtidx = pd.to_datetime(
        data[['Year', 'Month', 'Day', 'Hour', 'Minute']])
    tz = 'Etc/GMT%+d' % -metadata['Time Zone']
    data.index = pd.DatetimeIndex(dtidx).tz_localize(tz)

    # Rename PSM3 variable names to SAM-compatible names
    data = data.rename(columns=VARIABLE_MAP)
    # Rearrange columns to match the expected order
    #data = data[['Year', 'Month', 'Day', 'Hour', 'Minute', 'DNI', 'DHI', 'GHI', 'Dew Point', 'Temperature', 'Pressure', 'Wind Direction', 'Wind Speed', 'Surface Albedo']]
    data=data[['Year', 'Month', 'Day', 'Hour', 'Minute', 'dni', 'dhi', 'ghi', 'Dew Point', 'temp_air', 'pressure', 'wind_direction', 'wind_speed', 'albedo']]
    #Year	Month	Day	Hour	Minute	wind_speed	dhi	ghi	pressure	wind_direction	albedo	dni	temp_air	Dew Point

    # Add a "Timestamp" column
    #data['Timestamp'] = data.index.strftime('%Y%m%d:%H%M')

    # Create SAM-compatible file header
    header = [
        'Source,Location ID,City,State,Country,Latitude,Longitude,Time Zone,Elevation,Local Time Zone,Dew Point Units,DHI Units,DNI Units,GHI Units,Temperature Units,Pressure Units,Wind Direction Units,Wind Speed Units,Surface Albedo Units,Version\n',
        'NSRDB,{},-,-,-,{},{},{},{},{},C,w/m2,w/m2,w/m2,C,mbar,Degrees,m/s,N/A,3.1.0\n'.format(metadata["Location ID"], metadata["Latitude"], metadata["Longitude"], metadata["Time Zone"], metadata["Elevation"], metadata["Local Time Zone"]),
        'Year,Month,Day,Hour,Minute,DNI,DHI,GHI,Dew Point,Temperature,Pressure,Wind Direction,Wind Speed,Surface Albedo\n',
    ]
    header_str = ''.join(header)
    print(f"Debug: Reservoir name inside parse_psm3: {reservoir_name}")
    # Write SAM-compatible file
    sam_weather_file = f"sam_weather_file_{reservoir_name}+_{lat}_+{lon}.csv"
    with open(sam_weather_file, 'w') as sam_file:
        sam_file.write(header_str)
        data.to_csv(sam_file, index=False, header=False, sep=',')

    return data, metadata, sam_weather_file


def download_weather_data(lat, lon, reservoir_name):
    dataset = "2021"  ## fro souther brazil only 2019,2021, 2022 dta available
    '''
    if lat>=-21.186575058950382:
      dataset = "tmy-2021"
    else:
      dataset = "2021"
    '''
    #api_key = "qguVH9fdgUOyRo1jo6zzOUXkS6a96vY1ct45RpuK"
    #url = f"https://developer.nrel.gov/api/nsrdb/v2/solar/psm3-download.csv?wkt=POINT({lon}%20{lat})&names={dataset}&leap_day=false&interval=60&utc=false&full_name=Your%20Name&email=atiqureee@gmail.com&affiliation=Your%20Organization&mailing_list=true&reason=example&api_key={api_key}&attributes=dhi,dni,ghi,clearsky_dhi,clearsky_dni,clearsky_ghi,cloud_type,dew_point,air_temperature,surface_albedo,surface_pressure,relative_humidity,temperature_2m_nwp,precipitable_water,wind_direction_10m_nwp,wind_speed_10m_nwp,wind_speed_100m_nwp"

    #return StringIO(response.text)
    email='atiqureee@gmail.com'
    NREL_API_KEY='qguVH9fdgUOyRo1jo6zzOUXkS6a96vY1ct45RpuK'

    weather, metadata, sam_weather_file = get_psm3(lat, lon, NREL_API_KEY, email, names=dataset, interval=60,
                                                   attributes=('air_temperature', 'dew_point', 'dhi', 'dni', 'ghi',
                                                               'surface_albedo', 'surface_pressure', 'wind_direction',
                                                               'wind_speed'), leap_day=False, full_name='pvlib python',
                                                   affiliation='pvlib python', map_variables=None, timeout=60, reservoir_name=reservoir_name)
    print(f"Debug: Reservoir name inside download_weather_data: {reservoir_name}")
    temp_file = tempfile.NamedTemporaryFile(delete=False, suffix=".csv")
    temp_file.close()
    weather.to_csv(temp_file.name, index=False)

    # Create a new "Time" column using the "Year," "Month," "Day," and "Hour" columns
    weather["Time"] = pd.to_datetime(weather[["Year", "Month", "Day", "Hour"]])

    # Calculate average monthly albedo values
    weather["Month"] = pd.to_datetime(weather["Time"]).dt.month
    albedo_column = "albedo" if "albedo" in weather.columns else "Surface Albedo"
    monthly_albedo = weather.groupby("Month")[albedo_column].mean().tolist()


    return sam_weather_file, monthly_albedo, weather, metadata



def sapm_cell_FPV(poa_global, temp_air, wind_speed, a, b, deltaT,
              irrad_ref=1000.):

    module_temperature = sapm_module_FPV(poa_global, temp_air, wind_speed,
                                     a, b)
    return sapm_cell_from_module_FPV(module_temperature, poa_global, deltaT,
                                 irrad_ref)


def sapm_module_FPV(poa_global, temp_air, wind_speed, a, b):

    return poa_global * np.exp(a + b * wind_speed) + temp_air

def sapm_cell_from_module_FPV(module_temperature, poa_global, deltaT,
                          irrad_ref=1000.):

    return module_temperature + (poa_global / irrad_ref) * deltaT

def pvsyst_cell_fpv(poa_global, temp_air, wind_speed=1.0, u_c=29.0, u_v=0.0,
                eta_m=None, module_efficiency=0.1, alpha_absorption=0.9):

    if eta_m:
        warn_deprecated(
            since='v0.9', message='eta_m overwriting module_efficiency',
            name='eta_m', alternative='module_efficiency', removal='v0.10')
        module_efficiency = eta_m
    total_loss_factor = u_c + u_v * wind_speed
    heat_input = poa_global * alpha_absorption * (1 - module_efficiency)
    temp_difference = heat_input / total_loss_factor
    return temp_air + temp_difference

def pvsyst_cell_pv(poa_global, temp_air, wind_speed=1.0, u_c=29.0, u_v=0.0,
                eta_m=None, module_efficiency=0.1, alpha_absorption=0.9):

    if eta_m:
        warn_deprecated(
            since='v0.9', message='eta_m overwriting module_efficiency',
            name='eta_m', alternative='module_efficiency', removal='v0.10')
        module_efficiency = eta_m
    total_loss_factor = u_c + u_v * wind_speed
    heat_input = poa_global * alpha_absorption * (1 - module_efficiency)
    temp_difference = heat_input / total_loss_factor
    return temp_air + temp_difference


# Read the .xlsx file
filename = '/content/drive/MyDrive/techno-economicanalysisFPV/selected reservoirs_southernbrazil_aug23_v26.xlsx'
data = pd.read_excel(filename)
output_csv = "output.csv"
# Conversion factor for ET to E
conversion_factor_et_to_e = 0.8
# DataFrames to store the results
evaporation_df = pd.DataFrame()
rmse_results_E = {}
# DataFrames to store the results
evaporation_df = pd.DataFrame()



# Add this function to get the timezone for given latitude and longitude
def get_timezone(latitude, longitude):
    from timezonefinder import TimezoneFinder
    tf = TimezoneFinder()
    return tf.timezone_at(lat=latitude, lng=longitude)

# Define location (latitude, longitude, and timezone)
#tz = 'America/Sao_Paulo'


# Define system parameters
surface_tilt = 15  # degrees
surface_azimuth = 0  # degrees (south)
albedo = 0.20  # Albedo for water surface

# Define PV module and inverter parameters (replace with your module and inverter specs)
#cec_module_data = pvlib.pvsystem.retrieve_sam('CECMod')
#cec_inverter_data = pvlib.pvsystem.retrieve_sam('CECInverter')
#module = cec_module_data['Canadian_Solar_Inc__CS6X_320P']
#inverter = cec_inverter_data['ABB__MICRO_0_25_I_OUTD_US_240__240V_']

sandia_modules = pvlib.pvsystem.retrieve_sam('SandiaMod')
sandia_inverter = pvlib.pvsystem.retrieve_sam('SandiaInverter')
module = sandia_modules['Silevo_Triex_U300_Black__2014_']
inverter = sandia_inverter['Jiangsu_Zeversolar_New_Energy__Evershine_TL6000_US_240']
# Select the specific module and inverter
#print(sandia_inverters.columns[:5])
#print(sandia_modules.columns[:5])
#module = sandia_modules.loc[:, 523]
#inverter = sandia_inverters.loc[:, 1461]

# Economic parameters
system_cost_per_kw = 1000  # USD per kW
operation_maintenance_cost_per_kw = 20  # USD per kW per year
discount_rate = 0.04  # 7% discount rate
project_lifetime = 30  # years
electricity_price = 0.47  # USD per kWh

# Define specific power (W/m²) for the solar panels
specific_power = (module['Vmpo']*module['Impo'])/module['Area']
# Calculate NPV and LCOE for each row in the table

# Preallocate arrays for the results
num_rows = len(data.index)

#num_rows=1

Epen_all = np.zeros((2, 12, num_rows))
WS_all = np.zeros((12, num_rows))
# Preallocate arrays for the results
p_ac_all = np.zeros((12, num_rows))
p_ac_all_pv = np.zeros((12, num_rows))
npv_all = np.zeros(num_rows)
lcoe_all = np.zeros(num_rows)

p_ac_all_fpv_pv=np.zeros((2, 12, num_rows))


# Initialize the output DataFrame
#month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
#columns = ['reservoir_name', 'latitude', 'longitude', 'year', 'month', 'FPV_energy', 'PV_energy']
#monthly_data = pd.DataFrame(columns=columns)
column_names = ['reservoir_name', 'latitude', 'longitude', 'Annual_FPV_Energy_MWh', 'Annual_PV_Energy_MWh', 'state', 'reservoir_area','PanelArea_km2',]
# Add column names for each month
for i in range(1, 13):
    column_names.append(f'Month_{i}_FPV_Energy_kWh')
    column_names.append(f'Month_{i}_PV_Energy_kWh')

energy_data = pd.DataFrame(columns=column_names)


# Define your own loss percentages
my_soiling = 1
my_shading = 0  # No shading in your case, for example
my_snow = 0     # No snow in your case, for example
my_mismatch = 2
my_wiring = 2
my_connections = 0.5
my_lid = 2
my_nameplate_rating = 1
my_age = 0
my_availability = 1

# Calculate the total PVWatts loss factor
total_pvwatts_loss_factor = pvlib.pvsystem.pvwatts_losses(
    soiling=my_soiling, shading=my_shading, snow=my_snow,
    mismatch=my_mismatch, wiring=my_wiring, connections=my_connections,
    lid=my_lid, nameplate_rating=my_nameplate_rating, age=my_age,
    availability=my_availability
)





# Calculate the averages and store the results in the output DataFrame
# Define the number of days in each month
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

ac_scaled_fpv_list=[]
ac_scaled_ground_pv_list=[]


#data = pd.read_csv(input_csv)
data["PV annual energy (kWh)"] = 0.0

for index, row in data.iterrows():
    print(f"Running case number: {index} grid: {index}")

    lat = row['latitude_all']
    lon = row["longitude_all"]
    ReservoirArea = row['Reservoir_area_all_km2']
    reservoir_name = row["Reservoir_name_all"]
    state1=row["State_twoword_all"]
    state2=row["Rservoir state_All"]
    PanelArea = 0.1 * ReservoirArea

    if PanelArea > 6:
      PanelArea = 6


    #area_acres = PanelArea * 247.105  # Convert km² to acres
    #pv_kw = area_acres * (1 / 2.5) * 1000 # thye have given total areas 30% we already did that so area comes to acres

    module_area_m2_fromtotal_PVarea=(771/1265)*PanelArea*1000000
    sam_weather_file_data, albedo_data, weather_full_dataframe, metadata  = download_weather_data(lat, lon, reservoir_name)

    tz = get_timezone(lat, lon)  # Get the corresponding timezone

    # Create a Location object
    location = pvlib.location.Location(lat, lon, tz)

    #system_size = specific_power * module_area_m2_fromtotal_PVarea
    #main_system_size_kW=system_size/1000

    # Calculate the array tilt
    #array_tilt = np.arctan(1.2 * ReservoirArea) * 180 / np.pi
    array_tilt = surface_tilt

    single_module_area = module['Area']  # area of a single module in m^2
    total_module_area = module_area_m2_fromtotal_PVarea  # total module area in m^2

    # Calculate number of modules in series and parallel
    #Array_Ms = np.floor(total_module_area / single_module_area)
    #Array_Mp = np.ceil(system_size / (module['Vmpo']*module['Impo']))

    '''
    # Calculate the area for a single module
    single_module_area = module['Area']  # area of a single module in m^2
    # Calculate the total module area based on available PanelArea
    total_module_area = module_area_m2_fromtotal_PVarea  # total module area in m^2
    # Calculate the number of modules that can fit into the total module area
    total_modules = np.floor(total_module_area / single_module_area)  # using floor to get an integer
    # Calculate the number of modules in parallel based on system size
    Array_Mp = np.ceil(main_system_size_kW * 1000 / (module['Vmpo'] * module['Impo']))  # main_system_size_kW is in kW, convert to W
    # Calculate the number of modules in series based on total modules and modules in parallel
    Array_Ms = np.floor(total_modules / Array_Mp)
    # Re-calculate the total modules to align with Array_Ms and Array_Mp
    total_modules = Array_Ms * Array_Mp
    # Re-calculate the system size based on the final total modules
    system_size= total_modules * module['Vmpo'] * module['Impo']
    main_system_size_kW= system_size/ 1000  # Convert to kW
    '''
    # Inverter specifications
    Vdcmax = inverter['Vdcmax']  # Maximum DC voltage
    Idcmax = inverter['Idcmax']   # Maximum DC current

    # Module specifications
    Vmpo = module['Vmpo']  # Maximum power voltage
    Impo = module['Impo']   # Maximum power current

    # Calculate number of modules in series (Ns)
    Array_Ms = np.floor(Vdcmax / Vmpo)

    # Calculate number of modules in parallel (Np)
    Array_Mp = np.floor(Idcmax / Impo)

    # Calculate total number of modules (N_total)
    total_modules = Array_Ms * Array_Mp

    #system_size= total_modules * module['Vmpo'] * module['Impo']
    #main_system_size_kW= system_size/ 1000  # Convert to kW



    # Calculate the total number of modules that can fit into the available area
    Total_Modules_Area = ReservoirArea * 1e6 / single_module_area  # Convert km^2 to m^2
    # Calculate the total system size based on the total module area
    total_system_size = Total_Modules_Area * module['Vmpo'] * module['Impo']
    # Calculate the number of inverters needed
    N_inverters = np.ceil(total_system_size / inverter['Paco'])
    # Your main system size in kW now becomes
    main_system_size_kW = total_system_size / 1000  # Convert to kW

    # Calculate solar position
    solpos = location.get_solarposition(weather_full_dataframe.index)

    # Calculate GHI
    #GHI_CERES_calc = weather_full_dataframe['dni'] * pvlib.tools.cosd(solpos['apparent_zenith']) + weather_full_dataframe['dhi']

    # Create the weather data DataFrame with the calculated GHI
    weather_data = pd.DataFrame({'ghi': weather_full_dataframe['ghi'], 'dni': weather_full_dataframe['dni'], 'dhi': weather_full_dataframe['dhi'], 'temp_air': weather_full_dataframe['temp_air'], 'wind_speed': weather_full_dataframe['wind_speed']}, index=weather_full_dataframe.index)

    # Calculate extraterrestrial radiation
    #dni_extra = pvlib.ir
    dni_extra = pvlib.irradiance.get_extra_radiation(solpos.index)
    # Calculate airmass
    airmass = location.get_airmass(solar_position=solpos)
    # Calculate angle of incidence
    aoi = pvlib.irradiance.aoi(array_tilt, surface_azimuth, solpos['apparent_zenith'], solpos['azimuth'])




    # Calculate total irradiance
    total_irradiance = pvlib.irradiance.get_total_irradiance(
        surface_tilt=array_tilt,
        surface_azimuth=surface_azimuth,
        solar_zenith=solpos['apparent_zenith'],
        solar_azimuth=solpos['azimuth'],
        dni=weather_data['dni'],
        ghi=weather_data['ghi'],
        dhi=weather_data['dhi'],
        dni_extra=dni_extra,
        airmass=airmass['airmass_relative'],
        albedo=albedo,
        model='perez',
    )





    # Calculate cell temperature
    cell_temperature_ground_pv = pvlib.temperature.sapm_cell(
    poa_global=total_irradiance['poa_global'],
    temp_air=weather_data['temp_air'],
    wind_speed=weather_data['wind_speed'],
    **pvlib.temperature.TEMPERATURE_MODEL_PARAMETERS['sapm']['open_rack_glass_glass'],
        )


    # Calculate the cell temperature
    #temp_cell = pvsyst_cell_fpv(poa_global=total_irradiance['poa_global'], temp_air=ambient_temp, wind_speed=wind_speed, **module['temp_params'])
    temp_cell_fpv = pvsyst_cell_fpv(poa_global=total_irradiance['poa_global'], temp_air=weather_data['temp_air'], wind_speed=weather_data['wind_speed'], u_c=26.3, u_v=2,
            eta_m=None, module_efficiency=0.17, alpha_absorption=0.9)

    '''
    # Calculate the photocurrent, saturation current, and resistance values for the single diode model
    IL, I0, Rse, Rsh, nNsVth = pvlib.pvsystem.calcparams_desoto(
        total_irradiance['poa_global'],
        temp_cell_fpv,
        module['alpha_sc'],
        module['a_ref'],
        module['I_L_ref'],
        module['I_o_ref'],
        module['R_sh_ref'],
        module['R_s'],
        EgRef=1.121,  # This is the default value for crystalline silicon cells
    )
    #effective_irradiance, temp_cell, alpha_sc, a_ref,
    '''
    # This would replace your DeSoto model calculations
    sapm_out_fpv = pvlib.pvsystem.sapm(
        total_irradiance['poa_global'],
        temp_cell_fpv,
        module
    )

    dc = sapm_out_fpv['p_mp']
    ac = pvlib.inverter.sandia(dc, sapm_out_fpv['v_mp'], inverter)

    # Calculate the single diode model values
    #single_diode_output_fpv = pvlib.pvsystem.singlediode(IL, I0, Rse, Rsh, nNsVth)
    #dc = single_diode_output_fpv['p_mp']
    #ac = pvlib.inverter.sandia(single_diode_output_fpv['v_mp'], single_diode_output_fpv['p_mp'],inverter)

    # Extract the DC power from the single diode model output

    ## GROUND PV

    temp_cell_pv = pvsyst_cell_pv(poa_global=total_irradiance['poa_global'], temp_air=weather_data['temp_air'], wind_speed=weather_data['wind_speed'], u_c=25, u_v=1.2,
            eta_m=None, module_efficiency=0.17, alpha_absorption=0.9)
    '''
    # Calculate the photocurrent, saturation current, and resistance values for the single diode model
    IL, I0, Rse, Rsh, nNsVth = pvlib.pvsystem.calcparams_desoto(
        total_irradiance['poa_global'],
        temp_cell_pv,
        module['alpha_sc'],
        module['a_ref'],
        module['I_L_ref'],
        module['I_o_ref'],
        module['R_sh_ref'],
        module['R_s'],
        EgRef=1.121,  # This is the default value for crystalline silicon cells
    )
    '''
    sapm_out_pv = pvlib.pvsystem.sapm(
        total_irradiance['poa_global'],
        temp_cell_pv,
        module
    )

    dc_ground_pv= sapm_out_pv['p_mp']
    ac_ground_pv = pvlib.inverter.sandia(dc, sapm_out_pv['v_mp'], inverter)


    # Calculate the single diode model values
    #single_diode_output_pv = pvlib.pvsystem.singlediode(IL, I0, Rse, Rsh, nNsVth)
    #dc_ground_pv = single_diode_output_pv['p_mp']
    #ac_ground_pv = pvlib.inverter.sandia(single_diode_output_pv['v_mp'], single_diode_output_pv['p_mp'], inverter)

    ## inverter loss added
    P_nom = inverter['Paco']
    ac = np.minimum(ac, P_nom)
    ac_ground_pv = np.minimum(ac_ground_pv, P_nom)



    # Scale the PV output by the system size
    ac_scaled_fpv = (ac / (module['Vmpo']*module['Impo'])) * system_size
    ac_scaled_fpv2 = (ac / (module['Vmpo']*module['Impo'])) * system_size * (np.cos(np.deg2rad(array_tilt)) + 1.2 * np.sin(np.deg2rad(array_tilt)))

    ac_scaled_ground_pvff = (ac_ground_pv / (module['Vmpo']*module['Impo'])) * system_size
    ac_scaled_ground_pv2 = (ac_ground_pv / (module['Vmpo']*module['Impo'])) * system_size * (np.cos(np.deg2rad(array_tilt)) + 1.2 * np.sin(np.deg2rad(array_tilt)))

    cos_tilt = np.cos(np.deg2rad(array_tilt))
    sin_tilt = 1.2 * np.sin(np.deg2rad(array_tilt))
    ac_scaled_fpv2 = ac / (Array_Ms * Array_Mp * single_module_area * (cos_tilt + sin_tilt)) * 10**3
    ac_scaled_ground_pv2 = ac_ground_pv / (Array_Ms * Array_Mp * single_module_area * (cos_tilt + sin_tilt)) * 10**3


    ac_scaled_fpv3 = ac * N_inverters
    ac_scaled_ground_pv3=ac_ground_pv* N_inverters

    #ac_scaled_fpv_monthly = ac_scaled_fpv.resample('M').sum()
    #ac_scaled_fpv2_monthly = ac_scaled_fpv2.resample('M').sum()
    #ac_scaled_ground_pv_monthly = ac_scaled_ground_pv.resample('M').sum()
    #ac_scaled_ground_pv2_monthly = ac_scaled_ground_pv2.resample('M').sum()



    # Adjust the monthly energy outputs for losses
    #adjusted_monthly_fpv_energy = ac_scaled_fpv_monthly * (1 - total_pvwatts_loss_factor / 100)
    #adjusted_monthly_pv_energy = ac_scaled_ground_pv_monthly * (1 - total_pvwatts_loss_factor / 100)

    # Adjust the annual energy outputs for losses
    #adjusted_annual_fpv_energy = adjusted_monthly_fpv_energy.sum()
    #adjusted_annual_pv_energy = adjusted_monthly_pv_energy.sum()


    monthly_fpv_energy = ac_scaled_fpv3.resample('M').sum()* (1 - total_pvwatts_loss_factor / 100)  # This already contains monthly sums
    monthly_pv_energy = ac_scaled_ground_pv3.resample('M').sum()* (1 - total_pvwatts_loss_factor / 100)  # This already contains monthly sums
    annual_fpv_energy = monthly_fpv_energy.sum()/1000000
    annual_pv_energy = monthly_pv_energy.sum()/1000000
    # Create a dictionary to store all the data
    data_dict = {
        'reservoir_name': reservoir_name,
        'latitude': lat,
        'longitude': lon,
        'Annual_FPV_Energy_MWh': annual_fpv_energy,
        'Annual_PV_Energy_MWh': annual_pv_energy,
        'state': state1,
        'reservoir_area': ReservoirArea,
        'PanelArea_km2':PanelArea
    }

    # Add monthly data to the dictionary
    for i, (fpv, pv) in enumerate(zip(monthly_fpv_energy, monthly_pv_energy)):
        data_dict[f'Month_{i+1}_FPV_Energy_kWh'] = fpv/1000
        data_dict[f'Month_{i+1}_PV_Energy_kWh'] = pv/1000

    # Append this data to the energy_data DataFrame
    energy_data = energy_data.append(data_dict, ignore_index=True)
# Out:
# Running case number: 0 grid: 0
# Debug: Reservoir name inside parse_psm3: Itaipu, Parana
# Debug: Reservoir name inside download_weather_data: Itaipu, Parana
# <ipython-input-16-04f695e22c0b>:675: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   energy_data = energy_data.append(data_dict, ignore_index=True)
# Running case number: 1 grid: 1
# Debug: Reservoir name inside parse_psm3: Passo rea, Rio Grande do Sul
# Debug: Reservoir name inside download_weather_data: Passo rea, Rio Grande do Sul
# <ipython-input-16-04f695e22c0b>:675: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   energy_data = energy_data.append(data_dict, ignore_index=True)
# Running case number: 2 grid: 2
# Debug: Reservoir name inside parse_psm3: Campos novos, Santa Catarina
# Debug: Reservoir name inside download_weather_data: Campos novos, Santa Catarina
# <ipython-input-16-04f695e22c0b>:675: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   energy_data = energy_data.append(data_dict, ignore_index=True)
# Running case number: 3 grid: 3
# Debug: Reservoir name inside parse_psm3: Passauna, Parana
# Debug: Reservoir name inside download_weather_data: Passauna, Parana
# <ipython-input-16-04f695e22c0b>:675: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   energy_data = energy_data.append(data_dict, ignore_index=True)
# Running case number: 4 grid: 4
# Debug: Reservoir name inside parse_psm3: Ludesa, Santa Catarina
# Debug: Reservoir name inside download_weather_data: Ludesa, Santa Catarina
# <ipython-input-16-04f695e22c0b>:675: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   energy_data = energy_data.append(data_dict, ignore_index=True)
# Running case number: 5 grid: 5
# Debug: Reservoir name inside parse_psm3: Arroio duro, Rio Grande do Sul
# Debug: Reservoir name inside download_weather_data: Arroio duro, Rio Grande do Sul
# <ipython-input-16-04f695e22c0b>:675: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   energy_data = energy_data.append(data_dict, ignore_index=True)

# %%
# Save the energy_data DataFrame to a CSV file
energy_data.to_csv('energy_data.csv', index=False)
